# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import PolynomialFeatures, StandardScaler, MinMaxScaler
from sklearn.linear_model import LinearRegression, Ridge, Lasso
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score
from sklearn.preprocessing import LabelEncoder
from sklearn.impute import SimpleImputer
from sklearn.impute import KNNImputer

# %%
df1 = pd.read_csv('coches-de-segunda-mano-sample.csv')
df1
# Out:
#                                     url                           company  \
# 0      e158ae0ca53119ca199c28c36b5c2fcd  9881bcdd5a0ad4733037b3fb25e69c3a
# 1      ff267ebb7e700246f47f84f3db660b4b  9881bcdd5a0ad4733037b3fb25e69c3a
# 2      de4b02db28ea7786c622b969be10c7c7  9881bcdd5a0ad4733037b3fb25e69c3a
# 3      0449972a4d07594acf92e9a7dd28b39c  9881bcdd5a0ad4733037b3fb25e69c3a
# 4      12c4fa49bd4fdf23f19ecf396d3f02ef  9881bcdd5a0ad4733037b3fb25e69c3a
# ...                                 ...                               ...
# 49995  730210734bfbe1d3df878d5df71246f2  9881bcdd5a0ad4733037b3fb25e69c3a
# 49996  732b04fb47dd9559dbdcd099c5af484e  9881bcdd5a0ad4733037b3fb25e69c3a
# 49997  c10afb53957fb8012707239bdfa66018  9881bcdd5a0ad4733037b3fb25e69c3a
# 49998  f74363a6688ba11b71b4d980a959b8d3  9881bcdd5a0ad4733037b3fb25e69c3a
# 49999  3d60801ccb96ef038747130e8a34ceda  9881bcdd5a0ad4733037b3fb25e69c3a
#
#              make            model  \
# 0            SEAT           Toledo
# 1         CITROEN               C1
# 2            FORD  Transit Connect
# 3      VOLKSWAGEN        Caravelle
# 4            FORD          Transit
# ...           ...              ...
# 49995     HYUNDAI              i30
# 49996     RENAULT           Laguna
# 49997     PEUGEOT              108
# 49998        AUDI              RS4
# 49999     CITROEN               C2
#
#                                                  version  price  \
# 0                                       SEAT Toledo  4p.    950
# 1                 CITROEN C1 PureTech 60KW 82CV Feel 5p.   6200
# 2      FORD Transit Connect Van 1.5 TDCi 100cv Ambien...   7851
# 3      VOLKSWAGEN Caravelle Largo 2.0 TDI 140 Comfort...  19426
# 4      FORD Transit 350 96kW L4 Ambiente Propulsion T...  22850
# ...                                                  ...    ...
# 49995        HYUNDAI i30 1.4 TGDI Tecno Fastback DCT 5p.  18490
# 49996  RENAULT Laguna Coupe Limited 2.0 Energy dCi 15...  14500
# 49997           PEUGEOT 108 TOP Allure VTi 52kW 72CV 5p.  11000
# 49998           AUDI RS4 Avant 4.2 FSI 450cv quattro 5p.  47900
# 49999                    CITROEN C2 1.4 HDI VTR Plus 3p.   2790
#
#        price_financed      fuel    year     kms  ...  doors       shift  \
# 0                 NaN    Diésel  2000.0  227000  ...      4      Manual
# 1                 NaN  Gasolina  2017.0   50071  ...      5      Manual
# 2              7024.0    Diésel  2016.0  103000  ...      4      Manual
# 3                 NaN    Diésel  2014.0  120000  ...      4      Manual
# 4             22800.0    Diésel  2017.0  107000  ...      2      Manual
# ...               ...       ...     ...     ...  ...    ...         ...
# 49995         16490.0  Gasolina  2018.0   47000  ...      5  Automático
# 49996         13551.0    Diésel  2015.0   68750  ...      2      Manual
# 49997          9000.0  Gasolina  2019.0   21422  ...      5      Manual
# 49998             NaN  Gasolina  2013.0   47900  ...      5  Automático
# 49999             NaN    Diésel  2006.0  106000  ...      3      Manual
#
#                                 color photos  is_professional  \
# 0                               Verde      5            False
# 1                              Blanco      6             True
# 2                              Blanco     10             True
# 3                              Blanco      9             True
# 4                              Blanco      4             True
# ...                               ...    ...              ...
# 49995                    Gris / Plata     26             True
# 49996  KNG Gris Casiopea (metalizado)     30             True
# 49997                    Gris / Plata     17             True
# 49998        Gris / Plata (Antracita)     20             True
# 49999                           Negro     21             True
#
#                                  dealer   province country  \
# 0      0f4bb8455d27349b8273109b66a847f3    Navarra   Spain
# 1                         Autos Raymara   Tenerife   Spain
# 2                               Auto 96  Barcelona   Spain
# 3                              Inniauto    Navarra   Spain
# 4                  Autofleet España,s.l    Sevilla   Spain
# ...                                 ...        ...     ...
# 49995                   Flexicar Málaga     Málaga   Spain
# 49996                      Ocasion Plus     Málaga   Spain
# 49997                 Psa Retail Huelva     Huelva   Spain
# 49998                    Codigocar Lugo       Lugo   Spain
# 49999                   AUTOVALENCIA 19  Barcelona   Spain
#
#               publish_date          insert_date
# 0      2020-12-18 10:47:13  2021-01-15 00:00:00
# 1      2021-01-02 11:25:40  2021-01-15 00:00:00
# 2      2020-12-16 10:51:45  2021-01-15 00:00:00
# 3      2020-11-25 11:09:14  2021-01-15 00:00:00
# 4      2021-01-12 20:00:34  2021-01-15 00:00:00
# ...                    ...                  ...
# 49995  2020-11-24 19:59:52  2021-01-15 00:00:00
# 49996  2021-01-13 17:02:41  2021-01-15 00:00:00
# 49997  2021-01-08 16:47:24  2021-01-15 00:00:00
# 49998  2021-01-13 16:22:53  2021-01-15 00:00:00
# 49999  2021-01-10 16:32:41  2021-01-15 00:00:00
#
# [50000 rows x 21 columns]

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50000 entries, 0 to 49999
# Data columns (total 21 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   url              50000 non-null  object
#  1   company          50000 non-null  object
#  2   make             49998 non-null  object
#  3   model            49995 non-null  object
#  4   version          50000 non-null  object
#  5   price            50000 non-null  int64
#  6   price_financed   23563 non-null  float64
#  7   fuel             49954 non-null  object
#  8   year             49998 non-null  float64
#  9   kms              50000 non-null  int64
#  10  power            41472 non-null  float64
#  11  doors            50000 non-null  int64
#  12  shift            49889 non-null  object
#  13  color            49406 non-null  object
#  14  photos           50000 non-null  int64
#  15  is_professional  50000 non-null  bool
#  16  dealer           50000 non-null  object
#  17  province         49994 non-null  object
#  18  country          50000 non-null  object
#  19  publish_date     50000 non-null  object
#  20  insert_date      50000 non-null  object
# dtypes: bool(1), float64(3), int64(4), object(13)
# memory usage: 7.7+ MB

# %%
df1["fuel"].unique()
# Out:
# array(['Diésel', 'Gasolina', 'Híbrido enchufable', 'Eléctrico',
#        'Gas natural (CNG)', 'Híbrido', 'Gas licuado (GLP)', nan],
#       dtype=object)

# %%
df1.columns
# Out:
# Index(['url', 'company', 'make', 'model', 'version', 'price', 'price_financed',
#        'fuel', 'year', 'kms', 'power', 'doors', 'shift', 'color', 'photos',
#        'is_professional', 'dealer', 'province', 'country', 'publish_date',
#        'insert_date'],
#       dtype='object')

# %%
df1.drop(columns= ['url', 'company','dealer','price_financed','publish_date', 'insert_date','country'],inplace=True)

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50000 entries, 0 to 49999
# Data columns (total 14 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   make             49998 non-null  object
#  1   model            49995 non-null  object
#  2   version          50000 non-null  object
#  3   price            50000 non-null  int64
#  4   fuel             49954 non-null  object
#  5   year             49998 non-null  float64
#  6   kms              50000 non-null  int64
#  7   power            41472 non-null  float64
#  8   doors            50000 non-null  int64
#  9   shift            49889 non-null  object
#  10  color            49406 non-null  object
#  11  photos           50000 non-null  int64
#  12  is_professional  50000 non-null  bool
#  13  province         49994 non-null  object
# dtypes: bool(1), float64(2), int64(4), object(7)
# memory usage: 5.0+ MB

# %%
df1["province"].unique()
# Out:
# array(['Navarra', 'Tenerife', 'Barcelona', 'Sevilla', 'Madrid',
#        'Baleares', 'Alicante', 'Murcia', 'Guipúzcoa', 'Málaga', 'Jaén',
#        'Las Palmas', 'Granada', 'Lugo', 'Huelva', 'Asturias',
#        'Pontevedra', 'Córdoba', 'Zaragoza', 'León', 'A Coruña',
#        'Cantabria', 'Toledo', 'Vizcaya', 'Burgos', 'Lleida', 'Almería',
#        'Badajoz', 'Álava', 'Valencia', 'Cádiz', 'La Rioja', 'Girona',
#        'Ciudad Real', 'Ávila', 'Tarragona', 'Orense', 'Segovia',
#        'Cáceres', 'Cuenca', 'Albacete', 'Castellón', 'Guadalajara',
#        'Huesca', 'Teruel', 'Valladolid', 'Salamanca', 'Soria', 'Palencia',
#        'Zamora', 'Ceuta', nan, 'Melilla'], dtype=object)

# %%
df1["province"].value_counts()
# Out:
# province
# Madrid         9638
# Barcelona      5856
# Valencia       3533
# Sevilla        2552
# Málaga         2303
# Alicante       2103
# Vizcaya        1392
# Murcia         1364
# Las Palmas     1136
# Zaragoza       1055
# A Coruña        993
# Pontevedra      956
# Granada         890
# Tarragona       872
# Asturias        864
# Baleares        743
# Tenerife        727
# Badajoz         722
# Toledo          705
# Girona          650
# Navarra         649
# Castellón       641
# Córdoba         616
# Cádiz           605
# Valladolid      589
# Cantabria       560
# Guipúzcoa       526
# Jaén            489
# Burgos          487
# Almería         481
# Salamanca       471
# Lleida          469
# Ciudad Real     445
# Álava           409
# Albacete        375
# Lugo            369
# Huelva          366
# León            357
# Cáceres         326
# La Rioja        302
# Orense          237
# Guadalajara     188
# Huesca          163
# Ávila           143
# Cuenca          133
# Zamora          121
# Segovia         120
# Palencia        112
# Teruel          109
# Soria            53
# Melilla          16
# Ceuta            13
# Name: count, dtype: int64

# %%
filas_con_nan = df1[df1['province'].isnull()]

# %%
filas_con_nan
# Out:
#              make    model                                      version  \
# 4657         FORD   Fusion                FORD Fusion 1.4 TDCI Elegance
# 5010      HYUNDAI     Getz            HYUNDAI Getz 1.5 CRDi 88cv AA 5p.
# 10770        AUDI       A4              AUDI A4 Avant 2.0 TDI 140cv 5p.
# 14163  VOLKSWAGEN   Touran  VOLKSWAGEN Touran 2.0 TDI 140 Traveller 5p.
# 18125     CITROEN       C3                     CITROEN C3 1.4 HDi X 5p.
# 32024      SUBARU  Impreza                SUBARU Impreza 2.0R SPORT 5p.
#
#        price      fuel    year     kms  power  doors   shift  color  photos  \
# 4657     500    Diésel  2003.0  279000   68.0      5  Manual  Negro       5
# 5010    2500    Diésel  2006.0  132000   88.0      5  Manual  Negro       9
# 10770   5500    Diésel  2007.0  180000  140.0      5  Manual  Negro      10
# 14163   4990    Diésel  2007.0  268000  140.0      5  Manual  Negro       9
# 18125   2900    Diésel  2002.0  177572   70.0      5  Manual   Azul       6
# 32024   7500  Gasolina  2009.0  151000  150.0      5  Manual  Negro       9
#
#        is_professional province
# 4657             False      NaN
# 5010             False      NaN
# 10770            False      NaN
# 14163            False      NaN
# 18125            False      NaN
# 32024            False      NaN

# %% [markdown]
# voy a rellenar con madrid

# %%
marcas_con_nan = df1[df1['make'].isnull()]

# %%
marcas_con_nan
# Out:
#       make model        version  price       fuel    year  kms  power  doors  \
# 5659   NaN   D2S   D2S 27kW 3p.  21495  Eléctrico  2021.0    3   37.0      3
# 47381  NaN   D2S   D2S 27kW 3p.  21495  Eléctrico  2021.0    6   37.0      3
#
#             shift  color  photos  is_professional province
# 5659   Automático  Beige      16             True   Burgos
# 47381  Automático   Azul      15             True   Burgos

# %% [markdown]
# la marca es invicta

# %%
df1["make"].value_counts()
# Out:
# make
# VOLKSWAGEN        4624
# BMW               4510
# MERCEDES-BENZ     4227
# AUDI              3745
# PEUGEOT           3314
#                   ...
# DAIHATSU             1
# ALPINE               1
# VAZ                  1
# DR AUTOMOBILES       1
# LDV                  1
# Name: count, Length: 75, dtype: int64

# %%
df1["make"].unique()
# Out:
# array(['SEAT', 'CITROEN', 'FORD', 'VOLKSWAGEN', 'PEUGEOT', 'LAND-ROVER',
#        'HONDA', 'NISSAN', 'MERCEDES-BENZ', 'FIAT', 'SKODA', 'BMW',
#        'MAZDA', 'OPEL', 'AUDI', 'VOLVO', 'MITSUBISHI', 'RENAULT', 'KIA',
#        'DACIA', 'HYUNDAI', 'JEEP', 'SUZUKI', 'CHEVROLET', 'SSANGYONG',
#        'ABARTH', 'SMART', 'JAGUAR', 'TOYOTA', 'PORSCHE', 'SAAB', 'MINI',
#        'CHRYSLER', 'MG', 'IVECO', 'DS', 'CADILLAC', 'INFINITI',
#        'ASTON MARTIN', 'ALFA ROMEO', 'LEXUS', 'DODGE', 'TESLA',
#        'DR AUTOMOBILES', 'LANCIA', 'SUBARU', 'DAEWOO', 'BENTLEY',
#        'MASERATI', 'GALLOPER', 'ISUZU', 'ROVER', 'CUPRA', 'VAZ', 'DFSK',
#        nan, 'PONTIAC', 'FERRARI', 'MAHINDRA', 'TATA', 'CORVETTE',
#        'ALPINE', 'LAMBORGHINI', 'LOTUS', 'HUMMER', 'SANTANA', 'LADA',
#        'DAIHATSU', 'UMM', 'AUSTIN', 'MAXUS', 'MORGAN', 'ARO', 'PIAGGIO',
#        'IVECO-PEGASO', 'LDV'], dtype=object)

# %%
models_con_nan = df1[df1['model'].isnull()]

# %%
models_con_nan
# Out:
#        make model                               version  price    fuel  \
# 1330   SEAT   NaN                     SEAT Cordoba  5p.   1850  Diésel
# 25574  SEAT   NaN                      SEAT Toledo  4p.   1100  Diésel
# 31826  SEAT   NaN                                  SEAT   2400  Diésel
# 32831  SEAT   NaN                        SEAT Leon  5p.   3500  Diésel
# 37683  SEAT   NaN  SEAT Toledo 1.9 TDI STELLA 110CV 4p.    860  Diésel
#
#          year     kms  power  doors   shift         color  photos  \
# 1330   2004.0  248000    NaN      5  Manual  Gris / Plata       6
# 25574  2002.0  369000    NaN      4  Manual           NaN       4
# 31826  2008.0  370000    NaN      5  Manual  Gris / Plata       4
# 32831  2003.0  333000    NaN      5  Manual         Negro       5
# 37683  1999.0  367963  110.0      4  Manual  Gris / Plata      12
#
#        is_professional province
# 1330             False  Córdoba
# 25574            False   Toledo
# 31826            False   Toledo
# 32831            False     León
# 37683             True   Toledo

# %%
version_seat = df1[(df1['version']== "SEAT" )& (df1["year"]== 2008)]

# %%
version_seat_sorted = version_seat.sort_values(by='price')

# %%
version_seat_sorted
# Out:
#        make     model version  price      fuel    year     kms  power  doors  \
# 31826  SEAT       NaN    SEAT   2400    Diésel  2008.0  370000    NaN      5
# 45827  SEAT     Ibiza    SEAT   2400    Diésel  2008.0  303000    NaN      5
# 38466  SEAT   Córdoba    SEAT   2600  Gasolina  2008.0  167857    NaN      5
# 32694  SEAT   Córdoba    SEAT   2600    Diésel  2008.0  300000    NaN      5
# 28546  SEAT     Ibiza    SEAT   2650    Diésel  2008.0  298000    NaN      5
# 46176  SEAT      León    SEAT   2999    Diésel  2008.0  266000    NaN      5
# 9530   SEAT      León    SEAT   3200    Diésel  2008.0  228000    NaN      5
# 19672  SEAT     Ibiza    SEAT   3500    Diésel  2008.0  229000    NaN      5
# 43269  SEAT      León    SEAT   3600    Diésel  2008.0  241000    NaN      5
# 39370  SEAT     Ibiza    SEAT   3800    Diésel  2008.0  200000    NaN      5
# 18646  SEAT      León    SEAT   3800    Diésel  2008.0  171000    NaN      5
# 37424  SEAT     Ibiza    SEAT   3850  Gasolina  2008.0  135000    NaN      5
# 6435   SEAT     Ibiza    SEAT   3900    Diésel  2008.0   77000    NaN      3
# 11067  SEAT      León    SEAT   3900    Diésel  2008.0  245000    NaN      5
# 16630  SEAT  Altea XL    SEAT   3900    Diésel  2008.0  230000    NaN      5
# 15741  SEAT     ALTEA    SEAT   4399    Diésel  2008.0  227000    NaN      5
# 43971  SEAT     Ibiza    SEAT   4500    Diésel  2008.0  161000    NaN      3
# 45579  SEAT      León    SEAT   4700    Diésel  2008.0  206000    NaN      5
# 15727  SEAT      León    SEAT   4750    Diésel  2008.0     144    NaN      5
# 15098  SEAT      León    SEAT   4750    Diésel  2008.0  228000    NaN      5
# 27281  SEAT      León    SEAT   4899    Diésel  2008.0  173500    NaN      5
# 10231  SEAT      León    SEAT   5000    Diésel  2008.0     300    NaN      5
# 10867  SEAT     Ibiza    SEAT   5500    Diésel  2008.0   88000    NaN      5
# 9435   SEAT      León    SEAT   5500    Diésel  2008.0  294000    NaN      5
# 48878  SEAT      León    SEAT   6400    Diésel  2008.0  225000    NaN      5
# 21003  SEAT      León    SEAT   6600    Diésel  2008.0  108000    NaN      5
# 29665  SEAT      León    SEAT   6800    Diésel  2008.0  233000    NaN      5
# 20258  SEAT      León    SEAT  10990  Gasolina  2008.0  150000    NaN      5
#
#             shift         color  photos  is_professional   province
# 31826      Manual  Gris / Plata       4            False     Toledo
# 45827      Manual          Rojo      10            False     Burgos
# 38466      Manual  Gris / Plata       0            False     Málaga
# 32694      Manual  Gris / Plata       0            False     Toledo
# 28546      Manual  Gris / Plata       7            False   Tenerife
# 46176      Manual        Blanco       9            False  Barcelona
# 9530       Manual         Negro       8            False     Madrid
# 19672      Manual          Rojo       9            False     Madrid
# 43269      Manual  Gris / Plata       0            False     Murcia
# 39370      Manual        Blanco       0            False     Madrid
# 18646      Manual          Rojo       9            False    Almería
# 37424      Manual         Beige       0            False       Lugo
# 6435       Manual         Negro       7            False  Barcelona
# 11067      Manual  Gris / Plata       6            False     Madrid
# 16630      Manual           NaN       6            False  Barcelona
# 15741  Automático  Gris / Plata       9            False  Guipúzcoa
# 43971      Manual        Blanco       0            False    Vizcaya
# 45579      Manual        Blanco       3            False    Sevilla
# 15727      Manual  Gris / Plata       7            False    Granada
# 15098      Manual         Negro       9            False   A Coruña
# 27281      Manual  Gris / Plata       0            False    Sevilla
# 10231      Manual         Negro       0            False   A Coruña
# 10867      Manual         Negro       1            False  Barcelona
# 9435       Manual        Blanco       4            False  Barcelona
# 48878      Manual        Blanco       0            False   A Coruña
# 21003      Manual          Rojo       0            False   Zaragoza
# 29665      Manual         Negro       6            False  Cantabria
# 20258      Manual          Rojo       9            False    Almería

# %%
seat = df1[df1['make']== "SEAT"]
seat
# Out:
#        make   model                                            version  price  \
# 0      SEAT  Toledo                                   SEAT Toledo  4p.    950
# 34     SEAT   Ibiza        SEAT Ibiza 1.0 EcoTSI 81kW 110CV FR DSG 5p.  11400
# 47     SEAT    León             SEAT Leon 1.6 TDI 110cv StSp Style 5p.  10500
# 49     SEAT    León        SEAT Leon 2.0 TDI 110kW DSG7 SS FR Go L 5p.  26400
# 97     SEAT   Arona    SEAT Arona 1.6 TDI 85kW 115CV FR Editio Eco 5p.  19900
# ...     ...     ...                                                ...    ...
# 49939  SEAT   Ibiza                                    SEAT Ibiza  3p.   1500
# 49960  SEAT    León     SEAT Leon 1.5 EcoTSI 96kW 130CV StSp Style 5p.  14995
# 49986  SEAT   Arona      SEAT Arona 1.0 TSI 70kW 95CV Style Go Eco 5p.  18646
# 49993  SEAT    León  SEAT Leon ST 1.8 TSI 132kW 180CV StSp FR Plus 5p.  19490
# 49994  SEAT    León  SEAT Leon ST 1.6 TDI 85kW 115CV StSp Style Ed 5p.  18590
#
#            fuel    year     kms  power  doors       shift           color  \
# 0        Diésel  2000.0  227000    NaN      4      Manual           Verde
# 34     Gasolina  2017.0   28000  110.0      5  Automático           Negro
# 47       Diésel  2016.0  127000  110.0      5      Manual          Blanco
# 49       Diésel  2020.0      50  150.0      5  Automático           Negro
# 97       Diésel  2019.0   17788  115.0      5      Manual  Blanco (negro)
# ...         ...     ...     ...    ...    ...         ...             ...
# 49939    Diésel  2004.0  231000    NaN      3      Manual           Negro
# 49960  Gasolina  2019.0   19177  130.0      5      Manual            Rojo
# 49986  Gasolina  2020.0       0   95.0      5      Manual    Gris / Plata
# 49993  Gasolina  2017.0   67900  180.0      5      Manual          Blanco
# 49994    Diésel  2019.0   21153  115.0      5      Manual    Gris / Plata
#
#        photos  is_professional   province
# 0           5            False    Navarra
# 34          6            False  Barcelona
# 47         27             True  Cantabria
# 49         14             True     Toledo
# 97         22             True    Córdoba
# ...       ...              ...        ...
# 49939       5            False  Cantabria
# 49960      54             True   Alicante
# 49986      11             True     Madrid
# 49993      34             True  Barcelona
# 49994      20             True     Madrid
#
# [2604 rows x 14 columns]

# %%
seatdos = df1[(df1['make']== "SEAT")  & (df1["year"]== 2008)]
seatdos
# Out:
#        make     model                                      version  price  \
# 2034   SEAT      León  SEAT Leon 1.9 TDI 105cv Ecomotive Style 5p.   5500
# 2554   SEAT     Ibiza        SEAT Ibiza 1.4 16v 85cv Reference 3p.   4000
# 2878   SEAT      León         SEAT Leon 2.0 TDI 140cv Stylance 5p.   3000
# 4638   SEAT     Ibiza        SEAT Ibiza 1.2 12v 70cv Reference 5p.   4900
# 5592   SEAT     Ibiza        SEAT Ibiza 1.4 16v 85cv Reference 5p.   4900
# ...     ...       ...                                          ...    ...
# 47324  SEAT     Ibiza    SEAT Ibiza 1.9 TDI 105cv Stylance DPF 5p.   5300
# 48044  SEAT     Ibiza                              SEAT Ibiza  5p.   3500
# 48787  SEAT     Ibiza   SEAT Ibiza 1.9 TDI 105cv Reference DPF 5p.   4500
# 48878  SEAT      León                                         SEAT   6400
# 48947  SEAT  Altea XL       SEAT Altea XL 1.9 TDI 105cv Family 5p.   3000
#
#            fuel    year     kms  power  doors   shift            color  \
# 2034     Diésel  2008.0  219000  105.0      5  Manual             Azul
# 2554   Gasolina  2008.0   93000   85.0      3  Manual            Negro
# 2878     Diésel  2008.0  288000  140.0      5  Manual     Gris / Plata
# 4638   Gasolina  2008.0  120000   70.0      5  Manual  Blanco (BLANCO)
# 5592   Gasolina  2008.0  168337   85.0      5  Manual            Negro
# ...         ...     ...     ...    ...    ...     ...              ...
# 47324    Diésel  2008.0  179000  105.0      5  Manual            Negro
# 48044  Gasolina  2008.0  100000    NaN      5  Manual            Negro
# 48787    Diésel  2008.0  175000  105.0      5  Manual            Negro
# 48878    Diésel  2008.0  225000    NaN      5  Manual           Blanco
# 48947    Diésel  2008.0  280000  105.0      5  Manual           Blanco
#
#        photos  is_professional    province
# 2034        9             True   Salamanca
# 2554        8            False   Barcelona
# 2878        9            False   Barcelona
# 4638       17             True   Barcelona
# 5592        6             True      Málaga
# ...       ...              ...         ...
# 47324       8            False      Murcia
# 48044       2            False     Córdoba
# 48787       7             True  Pontevedra
# 48878       0            False    A Coruña
# 48947       8            False    Alicante
#
# [91 rows x 14 columns]

# %%
seatdos.head(97)
# Out:
#        make     model                                      version  price  \
# 2034   SEAT      León  SEAT Leon 1.9 TDI 105cv Ecomotive Style 5p.   5500
# 2554   SEAT     Ibiza        SEAT Ibiza 1.4 16v 85cv Reference 3p.   4000
# 2878   SEAT      León         SEAT Leon 2.0 TDI 140cv Stylance 5p.   3000
# 4638   SEAT     Ibiza        SEAT Ibiza 1.2 12v 70cv Reference 5p.   4900
# 5592   SEAT     Ibiza        SEAT Ibiza 1.4 16v 85cv Reference 5p.   4900
# ...     ...       ...                                          ...    ...
# 47324  SEAT     Ibiza    SEAT Ibiza 1.9 TDI 105cv Stylance DPF 5p.   5300
# 48044  SEAT     Ibiza                              SEAT Ibiza  5p.   3500
# 48787  SEAT     Ibiza   SEAT Ibiza 1.9 TDI 105cv Reference DPF 5p.   4500
# 48878  SEAT      León                                         SEAT   6400
# 48947  SEAT  Altea XL       SEAT Altea XL 1.9 TDI 105cv Family 5p.   3000
#
#            fuel    year     kms  power  doors   shift            color  \
# 2034     Diésel  2008.0  219000  105.0      5  Manual             Azul
# 2554   Gasolina  2008.0   93000   85.0      3  Manual            Negro
# 2878     Diésel  2008.0  288000  140.0      5  Manual     Gris / Plata
# 4638   Gasolina  2008.0  120000   70.0      5  Manual  Blanco (BLANCO)
# 5592   Gasolina  2008.0  168337   85.0      5  Manual            Negro
# ...         ...     ...     ...    ...    ...     ...              ...
# 47324    Diésel  2008.0  179000  105.0      5  Manual            Negro
# 48044  Gasolina  2008.0  100000    NaN      5  Manual            Negro
# 48787    Diésel  2008.0  175000  105.0      5  Manual            Negro
# 48878    Diésel  2008.0  225000    NaN      5  Manual           Blanco
# 48947    Diésel  2008.0  280000  105.0      5  Manual           Blanco
#
#        photos  is_professional    province
# 2034        9             True   Salamanca
# 2554        8            False   Barcelona
# 2878        9            False   Barcelona
# 4638       17             True   Barcelona
# 5592        6             True      Málaga
# ...       ...              ...         ...
# 47324       8            False      Murcia
# 48044       2            False     Córdoba
# 48787       7             True  Pontevedra
# 48878       0            False    A Coruña
# 48947       8            False    Alicante
#
# [91 rows x 14 columns]

# %%
seatdos["model"].unique()
# Out:
# array(['León', 'Ibiza', 'Córdoba', 'Altea XL', 'ALTEA', 'Altea Freetrack',
#        nan], dtype=object)

# %%
years_con_nan = df1[df1['year'].isnull()]

# %%
years_con_nan
# Out:
#        make   model                                            version  price  \
# 31025   KIA  Stonic         KIA Stonic 1.0 TGDi 74kW 100CV Concept 5p.  16850
# 42075  SEAT   Arona  SEAT Arona 1.0 TSI 85kW 115CV Xcellence Ecomot...  22500
#
#            fuel  year  kms  power  doors   shift  \
# 31025  Gasolina   NaN    1  100.0      5  Manual
# 42075  Gasolina   NaN    1  115.0      5  Manual
#
#                                          color  photos  is_professional  \
# 31025                  Signal Red (metalizado)      15             True
# 42075  Naranja Eclipse (metalizado) Techo Gris      14             True
#
#       province
# 31025  Sevilla
# 42075  Sevilla

# %%
df1["fuel"].unique()
# Out:
# array(['Diésel', 'Gasolina', 'Híbrido enchufable', 'Eléctrico',
#        'Gas natural (CNG)', 'Híbrido', 'Gas licuado (GLP)', nan],
#       dtype=object)

# %%
HYUNDAI = df1[(df1['make']== "HYUNDAI")  & (df1["model"]== "IONIQ")]

# %%
manu= HYUNDAI[HYUNDAI["shift"]=="Manual"]

# %%
manu
# Out:
#           make  model                                  version  price  \
# 6213   HYUNDAI  IONIQ                       HYUNDAI IONIQ  5p.  19500
# 26853  HYUNDAI  IONIQ                       HYUNDAI IONIQ  5p.  19500
# 31424  HYUNDAI  IONIQ               HYUNDAI IONIQ EV Style 5p.  27900
# 35328  HYUNDAI  IONIQ  HYUNDAI IONIQ 1.6 GDI HEV Tecno DCT 5p.  15900
# 43272  HYUNDAI  IONIQ  HYUNDAI IONIQ 1.6 GDI HEV Tecno DCT 5p.  18900
#
#             fuel    year    kms  power  doors   shift            color  \
# 6213         NaN  2019.0   9938    NaN      5  Manual           Blanco
# 26853        NaN  2019.0   7090    NaN      5  Manual     Gris / Plata
# 31424  Eléctrico  2019.0   3900  120.0      5  Manual  Blanco (BLANCO)
# 35328    Híbrido  2017.0  58370  141.0      5  Manual      Azul (AZUL)
# 43272    Híbrido  2017.0  42920  141.0      5  Manual  Blanco (BLANCO)
#
#        photos  is_professional province
# 6213       12             True   Huesca
# 26853      12             True   Huesca
# 31424      12             True  Vizcaya
# 35328      18             True     Lugo
# 43272      18             True     Lugo

# %%
fuels_con_nan = df1[df1['fuel'].isnull()]

# %%
fuels_con_nan
# Out:
#                 make      model                     version  price fuel  \
# 1921             BMW    Serie 6            BMW Serie 6  2p.  17000  NaN
# 1942            FIAT       Tipo              FIAT Tipo  5p.  13900  NaN
# 3293      ALFA ROMEO        147         ALFA ROMEO 147  3p.   4500  NaN
# 3896         RENAULT     Kangoo                     RENAULT   7000  NaN
# 6022   MERCEDES-BENZ    Clase C  MERCEDES-BENZ Clase C  3p.   2500  NaN
# 6213         HYUNDAI      IONIQ          HYUNDAI IONIQ  5p.  19500  NaN
# 7360            SEAT    Córdoba           SEAT Cordoba  5p.   1700  NaN
# 7660          TOYOTA      Auris           TOYOTA Auris  5p.  14500  NaN
# 9647            FORD      Focus             FORD Focus  5p.  23900  NaN
# 12732        HYUNDAI      IONIQ          HYUNDAI IONIQ  5p.  17900  NaN
# 12912            BMW    Serie 3                         BMW   7800  NaN
# 13696          LEXUS         NX               LEXUS NX  5p.  25000  NaN
# 19700     VOLKSWAGEN       Golf                  VOLKSWAGEN   7000  NaN
# 19764         TOYOTA      Auris           TOYOTA Auris  5p.  14990  NaN
# 20770     ALFA ROMEO  Giulietta   ALFA ROMEO Giulietta  5p.  18500  NaN
# 21269        HYUNDAI      IONIQ          HYUNDAI IONIQ  5p.  23200  NaN
# 21341          LEXUS         CT               LEXUS CT  5p.  10500  NaN
# 21345        PEUGEOT    Partner        PEUGEOT Partner  3p.  16500  NaN
# 23507            BMW    Serie 5                         BMW   6500  NaN
# 25407         TOYOTA      Auris           TOYOTA Auris  5p.   8800  NaN
# 26207        HYUNDAI      IONIQ          HYUNDAI IONIQ  5p.  18500  NaN
# 26639           FORD     Mondeo            FORD Mondeo  4p.  19900  NaN
# 26853        HYUNDAI      IONIQ          HYUNDAI IONIQ  5p.  19500  NaN
# 27609          LEXUS         NX                       LEXUS  26500  NaN
# 27752        HYUNDAI       Kona                HYUNDAI Kona  24950  NaN
# 28106        PEUGEOT    Partner        PEUGEOT Partner  5p.  18800  NaN
# 29139         TOYOTA      Auris           TOYOTA Auris  5p.  11900  NaN
# 29797         TOYOTA     Prius+                      TOYOTA   3500  NaN
# 31388           SEAT   Altea XL          SEAT Altea XL  5p.   3500  NaN
# 31675  MERCEDES-BENZ    Clase C  MERCEDES-BENZ Clase C  4p.  53500  NaN
# 31766        HYUNDAI      IONIQ          HYUNDAI IONIQ  5p.  19200  NaN
# 32999          LEXUS     RX400h                       LEXUS   9800  NaN
# 34308         TOYOTA      Auris                      TOYOTA   7500  NaN
# 35508        HYUNDAI      IONIQ          HYUNDAI IONIQ  5p.  23300  NaN
# 37609        PEUGEOT        206            PEUGEOT 206  3p.   3500  NaN
# 37786  MERCEDES-BENZ    Clase C  MERCEDES-BENZ Clase C  5p.  35695  NaN
# 38139         TOYOTA     Prius+                      TOYOTA   8800  NaN
# 39683        RENAULT      Twizy          RENAULT Twizy  2p.   4500  NaN
# 42717  MERCEDES-BENZ  Clase GLA     MERCEDES-BENZ Clase GLA  47900  NaN
# 43264         TOYOTA      Auris           TOYOTA Auris  5p.  13400  NaN
# 45381        RENAULT    Fluence                     RENAULT   3500  NaN
# 46365      CHEVROLET      Cruze        CHEVROLET Cruze  4p.   6900  NaN
# 47721           FIAT       Tipo              FIAT Tipo  5p.  21500  NaN
# 47744        HYUNDAI       Kona                HYUNDAI Kona  35990  NaN
# 48546     ALFA ROMEO  Giulietta   ALFA ROMEO Giulietta  5p.  15700  NaN
# 49130       INFINITI        Q50                    INFINITI  27900  NaN
#
#          year     kms  power  doors       shift  \
# 1921   2008.0  180000    NaN      2  Automático
# 1942   2019.0   31000    NaN      5      Manual
# 3293   2008.0  145345    NaN      3      Manual
# 3896   2012.0   44000    NaN      5  Automático
# 6022   2001.0  295000    NaN      3      Manual
# 6213   2019.0    9938    NaN      5      Manual
# 7360   2008.0  205555    NaN      5      Manual
# 7660   2016.0   71601    NaN      5  Automático
# 9647   2020.0       7    NaN      5      Manual
# 12732  2017.0   13163    NaN      5  Automático
# 12912  2001.0  370000    NaN      3      Manual
# 13696  2014.0  200000    NaN      5  Automático
# 19700  2006.0  270000    NaN      3      Manual
# 19764  2016.0   63465    NaN      5  Automático
# 20770  2019.0   25000    NaN      5      Manual
# 21269  2018.0   16580    NaN      5  Automático
# 21341  2012.0  132600    NaN      5  Automático
# 21345  2019.0      45    NaN      3  Automático
# 23507  2007.0  211000    NaN      5  Automático
# 25407  2015.0  185000    NaN      5  Automático
# 26207  2019.0   15584    NaN      5  Automático
# 26639  2018.0   54605  190.0      4      Manual
# 26853  2019.0    7090    NaN      5      Manual
# 27609  2015.0   60900    NaN      5  Automático
# 27752  2020.0     394    NaN      5  Automático
# 28106  2018.0    1500    NaN      5      Manual
# 29139  2015.0   65000    NaN      5      Manual
# 29797  2010.0  427000    NaN      5  Automático
# 31388  2014.0  300000    NaN      5      Manual
# 31675  2020.0     421    NaN      4      Manual
# 31766  2018.0   32830    NaN      5  Automático
# 32999  2007.0  298055    NaN      5  Automático
# 34308  2013.0  290000    NaN      5  Automático
# 35508  2018.0   18200    NaN      5  Automático
# 37609  2002.0  212000    NaN      3      Manual
# 37786  2019.0   13126  184.0      5  Automático
# 38139  2013.0  165271    NaN      5  Automático
# 39683  2012.0   39390    NaN      2  Automático
# 42717  2020.0     620    NaN      5  Automático
# 43264  2017.0   54907    NaN      5  Automático
# 45381  2013.0   59807    NaN      5  Automático
# 46365  2012.0  140000    NaN      4      Manual
# 47721  2019.0   14000    NaN      5  Automático
# 47744  2020.0      95    NaN      5  Automático
# 48546  2019.0   14500    NaN      5      Manual
# 49130  2014.0   24500    NaN      5  Automático
#
#                                              color  photos  is_professional  \
# 1921                                         Negro       0            False
# 1942          Gris / Plata (TRANSFORMADO GLP 14/8)       7             True
# 3293                                         Negro       0            False
# 3896                                        Blanco       4            False
# 6022                                          Azul       9            False
# 6213                                        Blanco      12             True
# 7360                                           NaN       3            False
# 7660                                          Azul      28             True
# 9647                                          Rojo      30             True
# 12732                                 Gris / Plata      21             True
# 12912                                         Azul       9            False
# 13696                                 Gris / Plata       5            False
# 19700                                        Negro       0            False
# 19764                                         Azul      12             True
# 20770            Negro (SE TRANSFORMA A  GLP 13/5)      19             True
# 21269                                       Blanco       0             True
# 21341                                         Rojo      10            False
# 21345                                       Blanco       8             True
# 23507                                         Azul       0            False
# 25407                                       Blanco       0            False
# 26207                                         Rojo       0             True
# 26639                                        Negro      19             True
# 26853                                 Gris / Plata      12             True
# 27609                                 Gris / Plata       0            False
# 27752                                         Azul       6             True
# 28106                                       Blanco      12             True
# 29139                                         Rojo       9            False
# 29797                                       Blanco       0            False
# 31388                                          NaN       9            False
# 31675       Gris / Plata (Gris grafito metalizado)       5             True
# 31766                                 Gris / Plata      31             True
# 32999                                        Negro       0            False
# 34308                                       Blanco       3            False
# 35508                                        Negro       6             True
# 37609                                        Negro       7            False
# 37786                 Gris / Plata (Gris Selenita)      18             True
# 38139                                         Rojo       4            False
# 39683                                        Negro       6            False
# 42717                    designo rojo Patagonia me      20             True
# 43264                                 Gris / Plata      16             True
# 45381                                 Gris / Plata       0            False
# 46365                                 Gris / Plata       9            False
# 47721  Negro (TRANSFORMACION DUAL FUEL JOR. LUCAS)      23             True
# 47744                                       Blanco       0             True
# 48546                    Blanco (TRANSFORMADO GLP)      20             True
# 49130                                 Gris / Plata       1            False
#
#          province
# 1921    Barcelona
# 1942       Madrid
# 3293       Madrid
# 3896     Tenerife
# 6022       Madrid
# 6213       Huesca
# 7360   Valladolid
# 7660      Badajoz
# 9647      Badajoz
# 12732     Badajoz
# 12912    Alicante
# 13696   Barcelona
# 19700       Ávila
# 19764     Granada
# 20770      Madrid
# 21269    Baleares
# 21341    Valencia
# 21345      Málaga
# 23507      Madrid
# 25407     Almería
# 26207    Asturias
# 26639      Madrid
# 26853      Huesca
# 27609   Cantabria
# 27752    Baleares
# 28106   Guipúzcoa
# 29139     Segovia
# 29797      Madrid
# 31388    Zaragoza
# 31675      Orense
# 31766     Badajoz
# 32999      Toledo
# 34308      Lleida
# 35508      Huesca
# 37609        Lugo
# 37786      Madrid
# 38139    Tenerife
# 39683       Cádiz
# 42717  Valladolid
# 43264      Málaga
# 45381    Baleares
# 46365    Alicante
# 47721      Madrid
# 47744   Guipúzcoa
# 48546      Madrid
# 49130      Murcia

# %%
relleno_modelos = {1330: "Córdoba", 25574:"Toledo", 31826: "Córdoba", 32831: "León", 37683: "Toledo"}

# %%
for indice, valor in relleno_modelos.items():
    df1.at[indice,'model']=valor

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50000 entries, 0 to 49999
# Data columns (total 14 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   make             49998 non-null  object
#  1   model            50000 non-null  object
#  2   version          50000 non-null  object
#  3   price            50000 non-null  int64
#  4   fuel             49954 non-null  object
#  5   year             49998 non-null  float64
#  6   kms              50000 non-null  int64
#  7   power            41472 non-null  float64
#  8   doors            50000 non-null  int64
#  9   shift            49889 non-null  object
#  10  color            49406 non-null  object
#  11  photos           50000 non-null  int64
#  12  is_professional  50000 non-null  bool
#  13  province         49994 non-null  object
# dtypes: bool(1), float64(2), int64(4), object(7)
# memory usage: 5.0+ MB

# %%
relleno_años = {31025: 2022.0, 42075: 2018.0}

# %%
for indice, valor in relleno_años.items():
    df1.at[indice,'year']=valor

# %%
relleno_fuel = {26639:"Híbrido",37786:"Gasolina"}

# %%
for indice, valor in relleno_fuel.items():
    df1.at[indice,'fuel']=valor

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50000 entries, 0 to 49999
# Data columns (total 14 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   make             49998 non-null  object
#  1   model            50000 non-null  object
#  2   version          50000 non-null  object
#  3   price            50000 non-null  int64
#  4   fuel             49956 non-null  object
#  5   year             50000 non-null  float64
#  6   kms              50000 non-null  int64
#  7   power            41472 non-null  float64
#  8   doors            50000 non-null  int64
#  9   shift            49889 non-null  object
#  10  color            49406 non-null  object
#  11  photos           50000 non-null  int64
#  12  is_professional  50000 non-null  bool
#  13  province         49994 non-null  object
# dtypes: bool(1), float64(2), int64(4), object(7)
# memory usage: 5.0+ MB

# %%
df1['make'] = df1['make'].fillna('INVICTA')

# %%
df1['province'] = df1['province'].fillna('Madrid')

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50000 entries, 0 to 49999
# Data columns (total 14 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   make             50000 non-null  object
#  1   model            50000 non-null  object
#  2   version          50000 non-null  object
#  3   price            50000 non-null  int64
#  4   fuel             49956 non-null  object
#  5   year             50000 non-null  float64
#  6   kms              50000 non-null  int64
#  7   power            41472 non-null  float64
#  8   doors            50000 non-null  int64
#  9   shift            49889 non-null  object
#  10  color            49406 non-null  object
#  11  photos           50000 non-null  int64
#  12  is_professional  50000 non-null  bool
#  13  province         50000 non-null  object
# dtypes: bool(1), float64(2), int64(4), object(7)
# memory usage: 5.0+ MB

# %%
df2 = df1.dropna(subset=['power'])

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 41472 entries, 1 to 49999
# Data columns (total 14 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   make             41472 non-null  object
#  1   model            41472 non-null  object
#  2   version          41472 non-null  object
#  3   price            41472 non-null  int64
#  4   fuel             41472 non-null  object
#  5   year             41472 non-null  float64
#  6   kms              41472 non-null  int64
#  7   power            41472 non-null  float64
#  8   doors            41472 non-null  int64
#  9   shift            41361 non-null  object
#  10  color            41369 non-null  object
#  11  photos           41472 non-null  int64
#  12  is_professional  41472 non-null  bool
#  13  province         41472 non-null  object
# dtypes: bool(1), float64(2), int64(4), object(7)
# memory usage: 4.5+ MB

# %%
fuels_con_na = df2[df2['fuel'].isnull()]

# %%
fuels_con_na
# Out:
# Empty DataFrame
# Columns: [make, model, version, price, fuel, year, kms, power, doors, shift, color, photos, is_professional, province]
# Index: []

# %%
MERCE = df1[(df1['make']== "MERCEDES-BENZ")  & (df1["model"]== "Clase C") & (df1["year"]== 2019)& (df1["power"]== 184)]

# %%
MERCE
# Out:
#                 make    model  \
# 589    MERCEDES-BENZ  Clase C
# 6376   MERCEDES-BENZ  Clase C
# 10771  MERCEDES-BENZ  Clase C
# 15359  MERCEDES-BENZ  Clase C
# 16105  MERCEDES-BENZ  Clase C
# 16813  MERCEDES-BENZ  Clase C
# 18091  MERCEDES-BENZ  Clase C
# 18305  MERCEDES-BENZ  Clase C
# 20349  MERCEDES-BENZ  Clase C
# 27349  MERCEDES-BENZ  Clase C
# 32004  MERCEDES-BENZ  Clase C
# 34716  MERCEDES-BENZ  Clase C
# 35763  MERCEDES-BENZ  Clase C
# 37786  MERCEDES-BENZ  Clase C
# 41102  MERCEDES-BENZ  Clase C
# 47022  MERCEDES-BENZ  Clase C
# 47202  MERCEDES-BENZ  Clase C
#
#                                                version  price      fuel  \
# 589              MERCEDES-BENZ Clase C Coupe C 200 2p.  39990   Híbrido
# 6376                   MERCEDES-BENZ Clase C C 200 4p.  33890  Gasolina
# 10771                  MERCEDES-BENZ Clase C C 200 4p.  36900   Híbrido
# 15359  MERCEDES-BENZ Clase C C 200 AMG Line Estate 5p.  33890  Gasolina
# 16105                  MERCEDES-BENZ Clase C C 200 4p.  33800   Híbrido
# 16813           MERCEDES-BENZ Clase C Cabrio C 200 2p.  39000   Híbrido
# 18091           MERCEDES-BENZ Clase C C Cabrio 200 2p.  37890  Gasolina
# 18305                  MERCEDES-BENZ Clase C C 200 4p.  34900   Híbrido
# 20349           MERCEDES-BENZ Clase C C Cabrio 200 2p.  40999  Gasolina
# 27349                  MERCEDES-BENZ Clase C C 200 4p.  39490   Híbrido
# 32004                  MERCEDES-BENZ Clase C C 200 4p.  32900   Híbrido
# 34716                  MERCEDES-BENZ Clase C C 200 4p.  33800   Híbrido
# 35763           MERCEDES-BENZ Clase C C Cabrio 200 2p.  40999  Gasolina
# 37786                       MERCEDES-BENZ Clase C  5p.  35695  Gasolina
# 41102           MERCEDES-BENZ Clase C C Cabrio 200 2p.  40999  Gasolina
# 47022           MERCEDES-BENZ Clase C C 200 Estate 5p.  40795   Híbrido
# 47202                  MERCEDES-BENZ Clase C C 200 4p.  33890  Gasolina
#
#          year    kms  power  doors       shift  \
# 589    2019.0  11560  184.0      2  Automático
# 6376   2019.0   9500  184.0      4  Automático
# 10771  2019.0   3284  184.0      4  Automático
# 15359  2019.0  17000  184.0      5  Automático
# 16105  2019.0   4238  184.0      4  Automático
# 16813  2019.0  26000  184.0      2  Automático
# 18091  2019.0  29000  184.0      2  Automático
# 18305  2019.0   5675  184.0      4  Automático
# 20349  2019.0   4074  184.0      2  Automático
# 27349  2019.0   8500  184.0      4  Automático
# 32004  2019.0  28950  184.0      4  Automático
# 34716  2019.0   5549  184.0      4  Automático
# 35763  2019.0   4074  184.0      2  Automático
# 37786  2019.0  13126  184.0      5  Automático
# 41102  2019.0   4074  184.0      2  Automático
# 47022  2019.0      1  184.0      5  Automático
# 47202  2019.0   9500  184.0      4  Automático
#
#                                   color  photos  is_professional   province
# 589                              Blanco      33             True   Valencia
# 6376       149 Blanco Polar (estÃ¡ndar)      48             True     Málaga
# 10771                            Blanco      16             True  Barcelona
# 15359      149 Blanco Polar (estÃ¡ndar)      12             True    Sevilla
# 16105           Gris / Plata (SELENITA)      21             True     Madrid
# 16813                            Blanco      13            False     Madrid
# 18091    992 Gris selenita (metalizado)      49             True     Málaga
# 18305             Blanco (Blanco Polar)      30             True     Málaga
# 20349  197 Negro obsidiana (metalizado)      11             True     Málaga
# 27349       Rojo (DESIGNO ROJO JACINTO)      25             True  Guipúzcoa
# 32004                    Blanco (Polar)      22             True     Madrid
# 34716                    Blanco (POLAR)       1             True     Madrid
# 35763  197 Negro obsidiana (metalizado)      11             True     Madrid
# 37786      Gris / Plata (Gris Selenita)      18             True     Madrid
# 41102  197 Negro obsidiana (metalizado)      11             True   Valencia
# 47022           Verde (Verde Esmeralda)      18             True     Madrid
# 47202      149 Blanco Polar (estÃ¡ndar)      48             True    Sevilla

# %%
colors_con_na = df2[df2['color'].isnull()]

# %%
colors_con_na
# Out:
#                  make       model  \
# 84              SKODA     Octavia
# 936              AUDI          A3
# 1108             FIAT         500
# 1109   DR AUTOMOBILES         DR3
# 1154             SEAT       Ibiza
# ...               ...         ...
# 48125            FORD      Fiesta
# 48491          NISSAN  Terrano II
# 48526            SEAT       Arona
# 48989           SKODA     Octavia
# 49592            FORD      Fiesta
#
#                                                  version  price  \
# 84     SKODA Octavia Combi 1.5 TGI 96kW130CV Ambit. C...  17490
# 936                 AUDI A3 1.4 TFSI gtron Sportback 5p.  17799
# 1108    FIAT 500 1.2 8v 51kW 69CV Hibrido Lounge GLP 3p.   9600
# 1109                      DR AUTOMOBILES DR3 1.5 GLP 5p.  16990
# 1154                 SEAT Ibiza 1.0 TGI 66kW 90CV FR 5p.  14500
# ...                                                  ...    ...
# 48125    FORD Fiesta 1.1 PFI GLP 55kW 75CV STLine 5p 5p.  14900
# 48491                       NISSAN Terrano II 2.4 SE 3p.   5000
# 48526        SEAT Arona 1.0 TGI 66kW 90CV FR Edition 5p.  20719
# 48989  SKODA Octavia Combi 1.5 TGI 96kW130CV Ambit. C...  19900
# 49592       FORD Fiesta 1.1 PFI GLP 55kW 75CV STLine 5p.  16970
#
#                     fuel    year     kms  power  doors       shift color  \
# 84     Gas natural (CNG)  2019.0   18000  130.0      5  Automático   NaN
# 936    Gas natural (CNG)  2017.0   67236  110.0      5      Manual   NaN
# 1108   Gas licuado (GLP)  2017.0   36309   69.0      3      Manual   NaN
# 1109   Gas licuado (GLP)  2020.0       1   98.0      5      Manual   NaN
# 1154   Gas natural (CNG)  2019.0   18571   90.0      5      Manual   NaN
# ...                  ...     ...     ...    ...    ...         ...   ...
# 48125  Gas licuado (GLP)  2019.0       8   75.0      5      Manual   NaN
# 48491           Gasolina  1997.0  200000  116.0      3      Manual   NaN
# 48526  Gas natural (CNG)  2020.0       0   90.0      5      Manual   NaN
# 48989  Gas natural (CNG)  2019.0    1133  130.0      5  Automático   NaN
# 49592  Gas licuado (GLP)  2019.0       0   75.0      5      Manual   NaN
#
#        photos  is_professional    province
# 84         33             True      Madrid
# 936         9             True      Málaga
# 1108        8             True    Valencia
# 1109       14             True      Málaga
# 1154       19             True      Madrid
# ...       ...              ...         ...
# 48125      14             True        León
# 48491       8            False   Barcelona
# 48526       7             True  Valladolid
# 48989      28             True    Valencia
# 49592      13             True   Barcelona
#
# [103 rows x 14 columns]

# %%
shifts_con_na = df2[df2['shift'].isnull()]

# %%
shifts_con_na
# Out:
#              make     model  \
# 541    VOLKSWAGEN      Golf
# 786       HYUNDAI     IONIQ
# 1537        MAZDA      CX-5
# 1666   VOLKSWAGEN      Golf
# 1980       JAGUAR    F-Pace
# ...           ...       ...
# 48193       DACIA    Dokker
# 48385     PEUGEOT       207
# 49248  VOLKSWAGEN  Multivan
# 49610        AUDI        A7
# 49837         KIA     XCeed
#
#                                                  version  price  \
# 541         VOLKSWAGEN Golf 1.6 TDI 105cv BlueMotion 5p.   8700
# 786               HYUNDAI IONIQ 1.6 GDI HEV Klass DT 5p.  18890
# 1537          MAZDA CX-5 2.2 DE 4WD AT Lux.P.T.SR CB 5p.  16800
# 1666       VOLKSWAGEN Golf Advance 1.6 TDI 105cv BMT 5p.  13400
# 1980    JAGUAR F-Pace 2.0L i4D 177kW RSport AWD Auto 5p.  36000
# ...                                                  ...    ...
# 48193        DACIA Dokker Ambiance dci 66kW 90CV N1 2017   9300
# 48385              PEUGEOT 207 SW Confort 1.6 HDI 90 5p.   3000
# 49248  VOLKSWAGEN Multivan 2.5 TDI 130cv Comfortline 5p.  15990
# 49610  AUDI A7 Sportback 3.0 TDI 245 quattro tiptroni...  19900
# 49837       KIA XCeed 1.6 GDi PHEV 104kW 141CV eTech 5p.  30500
#
#                      fuel    year     kms  power  doors shift         color  \
# 541                Diésel  2010.0   80000  105.0      5   NaN        Blanco
# 786               Híbrido  2019.0   16018  141.0      5   NaN  Gris / Plata
# 1537               Diésel  2014.0   95000  175.0      5   NaN         Negro
# 1666               Diésel  2015.0   32305  105.0      5   NaN        Blanco
# 1980               Diésel  2018.0  110000  240.0      5   NaN        Blanco
# ...                   ...     ...     ...    ...    ...   ...           ...
# 48193              Diésel  2017.0   85000   90.0      4   NaN        Blanco
# 48385              Diésel  2007.0  200000   90.0      5   NaN  Gris / Plata
# 49248              Diésel  2007.0  246000  130.0      5   NaN         Negro
# 49610              Diésel  2012.0  205000  245.0      5   NaN        Blanco
# 49837  Híbrido enchufable  2020.0   10004  141.0      5   NaN       Naranja
#
#        photos  is_professional    province
# 541        12            False     Cáceres
# 786        18             True     Sevilla
# 1537        8            False       Cádiz
# 1666       32             True      Madrid
# 1980        4            False      Murcia
# ...       ...              ...         ...
# 48193      13             True    Asturias
# 48385       6            False    Valencia
# 49248      24            False     Vizcaya
# 49610       8            False     Córdoba
# 49837      17             True  Pontevedra
#
# [111 rows x 14 columns]

# %%
df_limpio = df2.dropna(subset=['shift', 'color'])

# %%
df_limpio.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 41258 entries, 1 to 49999
# Data columns (total 14 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   make             41258 non-null  object
#  1   model            41258 non-null  object
#  2   version          41258 non-null  object
#  3   price            41258 non-null  int64
#  4   fuel             41258 non-null  object
#  5   year             41258 non-null  float64
#  6   kms              41258 non-null  int64
#  7   power            41258 non-null  float64
#  8   doors            41258 non-null  int64
#  9   shift            41258 non-null  object
#  10  color            41258 non-null  object
#  11  photos           41258 non-null  int64
#  12  is_professional  41258 non-null  bool
#  13  province         41258 non-null  object
# dtypes: bool(1), float64(2), int64(4), object(7)
# memory usage: 4.4+ MB

# %%
'''
mean_prices = df_limpio.groupby('make')['price'].mean().reset_index()

# Ordenar las marcas por la media del precio de menor a mayor
mean_prices_sorted = mean_prices.sort_values(by='price')

# Asignar un número a cada marca en función del orden
mean_prices_sorted['make_number'] = range(1, len(mean_prices_sorted) + 1)

# Unir esta información con el DataFrame original
df_limpio2 = df_limpio.merge(mean_prices_sorted[['make', 'make_number']], on='make', how='left')'''
# Out:
# "\nmean_prices = df_limpio.groupby('make')['price'].mean().reset_index()\n\n# Ordenar las marcas por la media del precio de menor a mayor\nmean_prices_sorted = mean_prices.sort_values(by='price')\n\n# Asignar un número a cada marca en función del orden\nmean_prices_sorted['make_number'] = range(1, len(mean_prices_sorted) + 1)\n\n# Unir esta información con el DataFrame original\ndf_limpio2 = df_limpio.merge(mean_prices_sorted[['make', 'make_number']], on='make', how='left')"

# %%
# Calcular la media de los precios por marca (make)
mean_prices_make = df_limpio.groupby('make')['price'].mean().reset_index()

# Ordenar las marcas por la media del precio de menor a mayor
mean_prices_make_sorted = mean_prices_make.sort_values(by='price')

# Asignar un número a cada marca en función del orden
mean_prices_make_sorted['make_number'] = range(1, len(mean_prices_make_sorted) + 1)

# Unir esta información con el DataFrame original
df_limpio2 = df_limpio.merge(mean_prices_make_sorted[['make', 'make_number']], on='make', how='left')

# Calcular la media de los precios por modelo (model)
mean_prices_model = df_limpio.groupby('model')['price'].mean().reset_index()

# Ordenar los modelos por la media del precio de menor a mayor
mean_prices_model_sorted = mean_prices_model.sort_values(by='price')

# Asignar un número a cada modelo en función del orden
mean_prices_model_sorted['model_number'] = range(1, len(mean_prices_model_sorted) + 1)

# Unir esta información con el DataFrame original
df_limpio2 = df_limpio2.merge(mean_prices_model_sorted[['model', 'model_number']], on='model', how='left')

# Visualizar el DataFrame resultante
print(df_limpio2.head())
# Out:
#          make            model  \
# 0     CITROEN               C1
# 1        FORD  Transit Connect
# 2  VOLKSWAGEN        Caravelle
# 3        FORD          Transit
# 4     PEUGEOT             3008
#
#                                              version  price      fuel    year  \
# 0             CITROEN C1 PureTech 60KW 82CV Feel 5p.   6200  Gasolina  2017.0
# 1  FORD Transit Connect Van 1.5 TDCi 100cv Ambien...   7851    Diésel  2016.0
# 2  VOLKSWAGEN Caravelle Largo 2.0 TDI 140 Comfort...  19426    Diésel  2014.0
# 3  FORD Transit 350 96kW L4 Ambiente Propulsion T...  22850    Diésel  2017.0
# 4         PEUGEOT 3008 Style 1.2 PureTech 130 SS 5p.  11490  Gasolina  2016.0
#
#       kms  power  doors   shift   color  photos  is_professional   province  \
# 0   50071   82.0      5  Manual  Blanco       6             True   Tenerife
# 1  103000  100.0      4  Manual  Blanco      10             True  Barcelona
# 2  120000  140.0      4  Manual  Blanco       9             True    Navarra
# 3  107000  130.0      2  Manual  Blanco       4             True    Sevilla
# 4   78665  130.0      5  Manual  Blanco      32             True     Madrid
#
#    make_number  model_number
# 0           20           328
# 1           24           376
# 2           38           681
# 3           24           476
# 4           29           613

# %%
df_limpio2
# Out:
#              make            model  \
# 0         CITROEN               C1
# 1            FORD  Transit Connect
# 2      VOLKSWAGEN        Caravelle
# 3            FORD          Transit
# 4         PEUGEOT             3008
# ...           ...              ...
# 41253     HYUNDAI              i30
# 41254     RENAULT           Laguna
# 41255     PEUGEOT              108
# 41256        AUDI              RS4
# 41257     CITROEN               C2
#
#                                                  version  price      fuel  \
# 0                 CITROEN C1 PureTech 60KW 82CV Feel 5p.   6200  Gasolina
# 1      FORD Transit Connect Van 1.5 TDCi 100cv Ambien...   7851    Diésel
# 2      VOLKSWAGEN Caravelle Largo 2.0 TDI 140 Comfort...  19426    Diésel
# 3      FORD Transit 350 96kW L4 Ambiente Propulsion T...  22850    Diésel
# 4             PEUGEOT 3008 Style 1.2 PureTech 130 SS 5p.  11490  Gasolina
# ...                                                  ...    ...       ...
# 41253        HYUNDAI i30 1.4 TGDI Tecno Fastback DCT 5p.  18490  Gasolina
# 41254  RENAULT Laguna Coupe Limited 2.0 Energy dCi 15...  14500    Diésel
# 41255           PEUGEOT 108 TOP Allure VTi 52kW 72CV 5p.  11000  Gasolina
# 41256           AUDI RS4 Avant 4.2 FSI 450cv quattro 5p.  47900  Gasolina
# 41257                    CITROEN C2 1.4 HDI VTR Plus 3p.   2790    Diésel
#
#          year     kms  power  doors       shift  \
# 0      2017.0   50071   82.0      5      Manual
# 1      2016.0  103000  100.0      4      Manual
# 2      2014.0  120000  140.0      4      Manual
# 3      2017.0  107000  130.0      2      Manual
# 4      2016.0   78665  130.0      5      Manual
# ...       ...     ...    ...    ...         ...
# 41253  2018.0   47000  140.0      5  Automático
# 41254  2015.0   68750  150.0      2      Manual
# 41255  2019.0   21422   72.0      5      Manual
# 41256  2013.0   47900  450.0      5  Automático
# 41257  2006.0  106000   70.0      3      Manual
#
#                                 color  photos  is_professional   province  \
# 0                              Blanco       6             True   Tenerife
# 1                              Blanco      10             True  Barcelona
# 2                              Blanco       9             True    Navarra
# 3                              Blanco       4             True    Sevilla
# 4                              Blanco      32             True     Madrid
# ...                               ...     ...              ...        ...
# 41253                    Gris / Plata      26             True     Málaga
# 41254  KNG Gris Casiopea (metalizado)      30             True     Málaga
# 41255                    Gris / Plata      17             True     Huelva
# 41256        Gris / Plata (Antracita)      20             True       Lugo
# 41257                           Negro      21             True  Barcelona
#
#        make_number  model_number
# 0               20           328
# 1               24           376
# 2               38           681
# 3               24           476
# 4               29           613
# ...            ...           ...
# 41253           35           454
# 41254           19           185
# 41255           29           372
# 41256           49           765
# 41257           20            95
#
# [41258 rows x 16 columns]

# %%
df_limpio2["model"].nunique()
# Out:
# 881

# %%
# Calcular la media del precio por cada modelo dentro de cada marca
mean_model_prices = df_limpio2.groupby(['make', 'model'])['price'].mean().reset_index()

# Ordenar los modelos dentro de cada marca por el precio medio
mean_model_prices = mean_model_prices.sort_values(by=['make', 'price'])

# Asignar un número a cada modelo dentro de cada marca en función del orden
mean_model_prices['model_numberdos'] = mean_model_prices.groupby('make').cumcount() + 1

# Unir esta información con el DataFrame original
df_limpio2 = df_limpio2.merge(mean_model_prices[['make', 'model', 'model_numberdos']], on=['make', 'model'], how='left')

# Crear una referencia única multiplicando make_number por 100 y sumando model_number
df_limpio2['make_model_ref'] = df_limpio2['make_number'] * 100 + df_limpio2['model_numberdos']

# %%
df_limpio2
# Out:
#              make            model  \
# 0         CITROEN               C1
# 1            FORD  Transit Connect
# 2      VOLKSWAGEN        Caravelle
# 3            FORD          Transit
# 4         PEUGEOT             3008
# ...           ...              ...
# 41253     HYUNDAI              i30
# 41254     RENAULT           Laguna
# 41255     PEUGEOT              108
# 41256        AUDI              RS4
# 41257     CITROEN               C2
#
#                                                  version  price      fuel  \
# 0                 CITROEN C1 PureTech 60KW 82CV Feel 5p.   6200  Gasolina
# 1      FORD Transit Connect Van 1.5 TDCi 100cv Ambien...   7851    Diésel
# 2      VOLKSWAGEN Caravelle Largo 2.0 TDI 140 Comfort...  19426    Diésel
# 3      FORD Transit 350 96kW L4 Ambiente Propulsion T...  22850    Diésel
# 4             PEUGEOT 3008 Style 1.2 PureTech 130 SS 5p.  11490  Gasolina
# ...                                                  ...    ...       ...
# 41253        HYUNDAI i30 1.4 TGDI Tecno Fastback DCT 5p.  18490  Gasolina
# 41254  RENAULT Laguna Coupe Limited 2.0 Energy dCi 15...  14500    Diésel
# 41255           PEUGEOT 108 TOP Allure VTi 52kW 72CV 5p.  11000  Gasolina
# 41256           AUDI RS4 Avant 4.2 FSI 450cv quattro 5p.  47900  Gasolina
# 41257                    CITROEN C2 1.4 HDI VTR Plus 3p.   2790    Diésel
#
#          year     kms  power  doors       shift  \
# 0      2017.0   50071   82.0      5      Manual
# 1      2016.0  103000  100.0      4      Manual
# 2      2014.0  120000  140.0      4      Manual
# 3      2017.0  107000  130.0      2      Manual
# 4      2016.0   78665  130.0      5      Manual
# ...       ...     ...    ...    ...         ...
# 41253  2018.0   47000  140.0      5  Automático
# 41254  2015.0   68750  150.0      2      Manual
# 41255  2019.0   21422   72.0      5      Manual
# 41256  2013.0   47900  450.0      5  Automático
# 41257  2006.0  106000   70.0      3      Manual
#
#                                 color  photos  is_professional   province  \
# 0                              Blanco       6             True   Tenerife
# 1                              Blanco      10             True  Barcelona
# 2                              Blanco       9             True    Navarra
# 3                              Blanco       4             True    Sevilla
# 4                              Blanco      32             True     Madrid
# ...                               ...     ...              ...        ...
# 41253                    Gris / Plata      26             True     Málaga
# 41254  KNG Gris Casiopea (metalizado)      30             True     Málaga
# 41255                    Gris / Plata      17             True     Huelva
# 41256        Gris / Plata (Antracita)      20             True       Lugo
# 41257                           Negro      21             True  Barcelona
#
#        make_number  model_number  model_numberdos  make_model_ref
# 0               20           328               22            2022
# 1               24           376               17            2417
# 2               38           681               31            3831
# 3               24           476               23            2423
# 4               29           613               38            2938
# ...            ...           ...              ...             ...
# 41253           35           454               22            3522
# 41254           19           185               15            1915
# 41255           29           372               26            2926
# 41256           49           765               33            4933
# 41257           20            95               10            2010
#
# [41258 rows x 18 columns]

# %%
df_limpio2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 41258 entries, 0 to 41257
# Data columns (total 18 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   make             41258 non-null  object
#  1   model            41258 non-null  object
#  2   version          41258 non-null  object
#  3   price            41258 non-null  int64
#  4   fuel             41258 non-null  object
#  5   year             41258 non-null  float64
#  6   kms              41258 non-null  int64
#  7   power            41258 non-null  float64
#  8   doors            41258 non-null  int64
#  9   shift            41258 non-null  object
#  10  color            41258 non-null  object
#  11  photos           41258 non-null  int64
#  12  is_professional  41258 non-null  bool
#  13  province         41258 non-null  object
#  14  make_number      41258 non-null  int64
#  15  model_number     41258 non-null  int64
#  16  model_numberdos  41258 non-null  int64
#  17  make_model_ref   41258 non-null  int64
# dtypes: bool(1), float64(2), int64(8), object(7)
# memory usage: 5.4+ MB

# %%
df_limpio2["make_model_ref"].unique()
# Out:
# array([2022, 2417, 3831, 2423, 2938, 6205, 3009, 2029, 3715, 3811, 5617,
#        1818, 3409, 2025, 1820, 2415, 2024, 5003, 2318, 4910, 5116, 3214,
#        2418, 1824, 5002, 2424, 1936, 2711, 5007, 2942, 2928, 4024, 2321,
#        3817, 1926, 2914, 2937, 3816, 2329, 2712, 5622, 5627, 1605, 1929,
#        3821, 5634, 4909, 2936, 5640, 5011, 2317, 3521, 5010, 2410, 2905,
#        5017, 3730, 5304, 3818, 3108, 2316, 1821, 5638, 2018, 5305, 2713,
#        1308, 2808, 4916, 1934, 4403, 5626, 2328, 4920, 4907, 5008, 2203,
#        3819, 5703, 3829, 5616, 5628, 5608, 2311, 1910, 2312, 2933, 3815,
#        3312, 4007, 4918, 3005, 4014, 1814, 1827, 3820, 5114, 2036, 3814,
#        4926, 3314, 3735, 1305, 5104, 2927, 2810, 3525, 3526, 2325, 6710,
#        2704, 5019, 2014, 2033, 2038, 1831, 1823, 4908, 2403, 2918, 5014,
#        3111, 2715, 2902, 5009, 2332, 5609, 3517, 2413, 2935, 5112, 1930,
#        2934, 3522, 2013, 1924, 5624, 5005, 5012, 2041, 2023, 4011, 5635,
#        4922, 2419, 1939, 3726, 3323, 1826, 4104, 3216, 5121, 3215, 1313,
#        3822, 5118, 2917, 3823, 2404, 4017, 4016, 5021, 5006, 4914, 2925,
#        5623, 3311, 3828, 6203, 3528, 3809, 3327, 2019, 1601,  905, 3613,
#        6707, 1816, 2320, 4101, 2031, 5013,  401, 1935, 1915, 4919, 2427,
#        6705, 5018, 1604, 5639, 6708, 1603, 5649, 2026, 1932, 2906, 1925,
#        3901, 6706, 2926, 3410, 4023, 3321, 3720, 5506, 3810, 3834, 4025,
#        2505, 3739, 2434, 2429, 3515, 3210, 1310, 5706, 2319, 4610, 1829,
#        1810, 2915, 3610, 1819, 5507, 3328, 5621, 1933, 5107, 3411, 2426,
#        3729, 1940, 3405, 2421, 3503, 3514, 1602, 2315, 3519, 2941, 4915,
#        3309, 3529, 2333, 5117, 2911, 2035, 1920, 5629, 2807, 4012, 6201,
#        6902, 4309, 3724, 4030, 5001, 5625, 3741, 4303, 5306, 2932, 5016,
#        5705, 6208, 4604, 5612, 5415, 3742, 3014, 3512, 6209, 4311, 3325,
#        2302, 1822, 2706, 5633, 2929, 3316, 3608, 5620, 3213, 2910, 2330,
#        3606, 3107, 4028, 1938, 2809, 4312, 2412, 4905, 3505, 2324, 4301,
#        5642, 2034, 4931, 1909, 1811, 2714, 6502,  802, 6905, 5015, 4605,
#        3412, 4103, 2431, 4913, 3102, 2009, 3702, 5631, 5709, 1302, 4013,
#        3604, 3827, 4707, 4603, 1923, 2940, 5701, 3322, 2939, 3330, 3315,
#        5119, 6204, 5115, 1201, 4015, 4705, 1917, 4704, 5505, 2408, 4008,
#        6703, 3317, 4402, 3520, 2307, 3106, 3805, 4930, 2707, 2804,  903,
#        5109, 1830, 3832, 2314, 2422, 2930, 2004, 3826, 3206, 1309, 1833,
#        5702, 3212, 2411, 5503, 4307, 2716, 3722, 5708, 1828, 5630, 4928,
#        6501, 1808, 3013, 5643, 5122, 2032, 3011, 4026, 2921, 5501, 3003,
#        3318, 2204, 2405, 5710, 2017,  106, 3740, 3209, 1806, 3414, 2702,
#        5614, 5644, 3808, 3605, 3609, 3313, 2943, 5413, 5405, 6701, 7001,
#        1928, 3329, 3813, 3737, 2916, 3113, 2414, 3112, 2420, 3824, 3109,
#        4936, 5108, 2313, 2011, 3403, 1203, 5619, 2304, 5637, 5022, 3518,
#        2010, 5110, 5105, 2708, 5711, 4021, 5632, 2331, 2705, 6603, 4019,
#        3302, 5004, 3714, 1913, 2021, 5704, 5641, 3612, 5618, 5611, 5902,
#        2409, 5408, 2310, 2433, 3506, 4005, 2432, 4010, 5307, 3703, 2909,
#        1914, 3504, 2710, 6606,  909, 5610, 3012, 3746, 5414, 2912, 4933,
#        4921, 1825, 3507, 5120, 1108, 3217, 3527, 4031, 3721, 1315, 3509,
#        1307, 3745, 5602, 3205, 1908, 3324, 6602, 4702, 6202, 5308, 2402,
#        4923, 2305, 1312, 5412,  105, 3413, 2430, 3326, 4937, 1109, 3723,
#        3803, 4939, 5401, 1809, 1906, 4022, 2039, 5645, 6302, 1911,  908,
#        3706, 2435, 3614, 6207, 2030, 1804, 3731, 4924, 5417, 4917, 5416,
#        4941, 3738, 5406, 2931, 2416,  910, 5707, 3513, 2428, 1107, 4903,
#        4701, 3902, 5303, 2913, 6206, 4009, 2406,  101, 5407, 5502, 4305,
#        4703, 6901, 4901, 3305, 2919, 3319,  107, 2326, 3734, 3406, 1314,
#        2336, 3332, 4306, 3733, 4938, 2922, 6709, 3602, 5202, 5203, 4102,
#        2037, 4801, 4609, 6607, 3705, 2006, 2601, 3732, 4308, 1805, 4710,
#        7112, 4029, 3837, 3825, 4020, 1311, 7107, 3615, 4929, 1106, 2334,
#        4205, 5646, 6303, 2002, 3718, 2908,  801,  301, 4925, 7106, 3303,
#        3812, 1815, 3603, 2709, 4934, 3202, 4706, 3402, 4201, 3308, 5504,
#        2903, 2805, 3801, 5418, 3115, 2016, 5106, 3530, 3833, 5411, 3304,
#        1918, 3502, 1303, 3830, 2327, 5509, 6401, 1306, 3407, 7004, 3836,
#        5023, 3006, 6702, 1301, 2020, 3110, 5419, 6301, 3743, 2924, 5647,
#        2306, 2504, 5420, 2028,  602, 5113, 3207, 1905, 4302, 5607, 3007,
#        3404,  904, 1105, 2811, 1205, 6904, 2501, 2907, 6801, 5301, 1937,
#        7203, 7005, 4304, 2308, 3744, 1907, 1803, 4906, 3204, 5636, 5604,
#        2301, 3103, 2806, 5020, 2920, 2027,  907, 3511, 6001, 1304, 2322,
#        1931, 5111, 4607, 3105, 3408, 7110, 4608, 3607, 2425, 1202, 4027,
#        2005,  104, 3307, 2703, 5403, 4018, 2303, 3807, 5101, 3736,  906,
#         103, 5204, 5901, 2003, 5651, 3719, 3717, 4204, 3713, 3611, 3806,
#        4911, 3008, 3524, 1832, 4932,  703, 3501, 1916, 1102, 7109, 4708,
#         702, 1003, 7003, 2803,  701, 3301, 7102, 6712, 4912, 1912, 3211,
#        2801, 2502, 5613, 5410, 2015, 6604, 2012, 5302, 5650, 5648, 1927,
#        2001, 3104, 7105,  302, 6704, 6711, 1901, 5103, 1807, 5605, 3711,
#        4606, 7201, 5508, 6605,  601, 1919, 4904, 4927, 3701, 6503, 1104,
#        6903, 3002, 5402, 3508, 1834,  901,  603,  501, 3401, 2401, 4940,
#        1401, 5615, 4935, 4002,  704, 1101,  402, 4401, 3331, 1904, 4709,
#        1501, 6101, 7202, 4601, 1801, 2040, 1817, 3707, 1103, 3704, 2802,
#        5102, 3510, 1941, 3516, 2701, 2008, 3835, 2407, 2904, 3802, 4202,
#        5606, 4501, 5404, 5601, 3708,  902,  303, 3114, 1802, 3320, 4902,
#        7111, 2901, 5801, 3804, 7104, 3709,  102, 2923, 3710, 2323, 3310,
#        3728, 4003, 1813, 2101, 1812, 2202, 2309, 3523,  706, 4006, 3306,
#        3101, 2201, 4602, 4001, 3727, 2602, 3203, 5201, 3725,  304, 2503,
#        1204, 7002, 1921, 3208, 5603, 3004, 4310, 1902, 7006, 1922, 4404,
#        4203, 2335, 5409, 6601, 4004,  201, 1002, 3001, 2007, 3712, 3716,
#        7101, 3201, 1701, 3601, 1001, 1316, 7103, 3010, 7108,  705, 1903],
#       dtype=int64)

# %%
df_limpio2["fuel"].unique()
# Out:
# array(['Gasolina', 'Diésel', 'Híbrido enchufable', 'Eléctrico',
#        'Gas natural (CNG)', 'Híbrido', 'Gas licuado (GLP)'], dtype=object)

# %%
my_fuel = {
    "Diésel": 0,
    "Gasolina": 1,
    "Gas natural (CNG)": 2,
    "Gas licuado (GLP)": 3,
    "Híbrido": 4,
    "Híbrido enchufable": 5,
    "Eléctrico": 6
}

df_limpio2['combustible_int'] = df_limpio2['fuel'].map(my_fuel)
df_limpio2.head()
# Out:
#          make            model  \
# 0     CITROEN               C1
# 1        FORD  Transit Connect
# 2  VOLKSWAGEN        Caravelle
# 3        FORD          Transit
# 4     PEUGEOT             3008
#
#                                              version  price      fuel    year  \
# 0             CITROEN C1 PureTech 60KW 82CV Feel 5p.   6200  Gasolina  2017.0
# 1  FORD Transit Connect Van 1.5 TDCi 100cv Ambien...   7851    Diésel  2016.0
# 2  VOLKSWAGEN Caravelle Largo 2.0 TDI 140 Comfort...  19426    Diésel  2014.0
# 3  FORD Transit 350 96kW L4 Ambiente Propulsion T...  22850    Diésel  2017.0
# 4         PEUGEOT 3008 Style 1.2 PureTech 130 SS 5p.  11490  Gasolina  2016.0
#
#       kms  power  doors   shift   color  photos  is_professional   province  \
# 0   50071   82.0      5  Manual  Blanco       6             True   Tenerife
# 1  103000  100.0      4  Manual  Blanco      10             True  Barcelona
# 2  120000  140.0      4  Manual  Blanco       9             True    Navarra
# 3  107000  130.0      2  Manual  Blanco       4             True    Sevilla
# 4   78665  130.0      5  Manual  Blanco      32             True     Madrid
#
#    make_number  model_number  model_numberdos  make_model_ref  combustible_int
# 0           20           328               22            2022                1
# 1           24           376               17            2417                0
# 2           38           681               31            3831                0
# 3           24           476               23            2423                0
# 4           29           613               38            2938                1

# %%
label_encoder = LabelEncoder()

# Codificar las provincias
df_limpio2['provincia_numero'] = label_encoder.fit_transform(df_limpio2['province'])

# %%
df_limpio2["shift"].unique()
# Out:
# array(['Manual', 'Automático'], dtype=object)

# %%
my_cambio = {
    "Manual": 0,
    "Automático": 1
}

df_limpio2['cambio_int'] = df_limpio2['shift'].map(my_cambio)
df_limpio2.head()
# Out:
#          make            model  \
# 0     CITROEN               C1
# 1        FORD  Transit Connect
# 2  VOLKSWAGEN        Caravelle
# 3        FORD          Transit
# 4     PEUGEOT             3008
#
#                                              version  price      fuel    year  \
# 0             CITROEN C1 PureTech 60KW 82CV Feel 5p.   6200  Gasolina  2017.0
# 1  FORD Transit Connect Van 1.5 TDCi 100cv Ambien...   7851    Diésel  2016.0
# 2  VOLKSWAGEN Caravelle Largo 2.0 TDI 140 Comfort...  19426    Diésel  2014.0
# 3  FORD Transit 350 96kW L4 Ambiente Propulsion T...  22850    Diésel  2017.0
# 4         PEUGEOT 3008 Style 1.2 PureTech 130 SS 5p.  11490  Gasolina  2016.0
#
#       kms  power  doors   shift  ... photos  is_professional   province  \
# 0   50071   82.0      5  Manual  ...      6             True   Tenerife
# 1  103000  100.0      4  Manual  ...     10             True  Barcelona
# 2  120000  140.0      4  Manual  ...      9             True    Navarra
# 3  107000  130.0      2  Manual  ...      4             True    Sevilla
# 4   78665  130.0      5  Manual  ...     32             True     Madrid
#
#   make_number  model_number  model_numberdos  make_model_ref  combustible_int  \
# 0          20           328               22            2022                1
# 1          24           376               17            2417                0
# 2          38           681               31            3831                0
# 3          24           476               23            2423                0
# 4          29           613               38            2938                1
#
#    provincia_numero  cambio_int
# 0                42           0
# 1                 7           0
# 2                33           0
# 3                39           0
# 4                29           0
#
# [5 rows x 21 columns]

# %%
df_limpio2['prof_int'] = df_limpio2['is_professional'].astype(int)
df_limpio2.head()
# Out:
#          make            model  \
# 0     CITROEN               C1
# 1        FORD  Transit Connect
# 2  VOLKSWAGEN        Caravelle
# 3        FORD          Transit
# 4     PEUGEOT             3008
#
#                                              version  price      fuel    year  \
# 0             CITROEN C1 PureTech 60KW 82CV Feel 5p.   6200  Gasolina  2017.0
# 1  FORD Transit Connect Van 1.5 TDCi 100cv Ambien...   7851    Diésel  2016.0
# 2  VOLKSWAGEN Caravelle Largo 2.0 TDI 140 Comfort...  19426    Diésel  2014.0
# 3  FORD Transit 350 96kW L4 Ambiente Propulsion T...  22850    Diésel  2017.0
# 4         PEUGEOT 3008 Style 1.2 PureTech 130 SS 5p.  11490  Gasolina  2016.0
#
#       kms  power  doors   shift  ... is_professional   province  make_number  \
# 0   50071   82.0      5  Manual  ...            True   Tenerife           20
# 1  103000  100.0      4  Manual  ...            True  Barcelona           24
# 2  120000  140.0      4  Manual  ...            True    Navarra           38
# 3  107000  130.0      2  Manual  ...            True    Sevilla           24
# 4   78665  130.0      5  Manual  ...            True     Madrid           29
#
#   model_number  model_numberdos  make_model_ref  combustible_int  \
# 0          328               22            2022                1
# 1          376               17            2417                0
# 2          681               31            3831                0
# 3          476               23            2423                0
# 4          613               38            2938                1
#
#    provincia_numero  cambio_int  prof_int
# 0                42           0         1
# 1                 7           0         1
# 2                33           0         1
# 3                39           0         1
# 4                29           0         1
#
# [5 rows x 22 columns]

# %%
df_limpio2["color"].value_counts()
# Out:
# color
# Blanco                                              9647
# Gris / Plata                                        7943
# Negro                                               6252
# Azul                                                3982
# Rojo                                                2316
#                                                     ...
# Granate (Polar)                                        1
# Blanco (Blanco Perlado / Techo Negro Metalizado)       1
# Negro (Negro Diamond)                                  1
# Azul (Mediterraneo)                                    1
# Azul (OFERTA MES!!! ENTREGA INMEDIATA!!!)              1
# Name: count, Length: 3529, dtype: int64

# %%
import re
def limpiar_nombre(nombre):
    return re.sub(r'\([^)]*\)', '', nombre).strip()

# Aplicar la función al DataFrame
df_limpio2['color_limpio'] = df_limpio2['color'].apply(limpiar_nombre)

# %%
df_limpio2["color_limpio"].unique()
# Out:
# array(['Blanco', 'Azul', 'Gris / Plata', '296 Blanco Gelato', 'Granate',
#        'Negro', 'Rojo', 'Cassa White', 'Z2Z2 Azul Noche',
#        '369 Blanco Glaciar', 'Marrón', 'M0VG Gris vapor',
#        'GAZ Blanco Ion', 'A90 Sophistograu, efecto de brillo', 'Beige',
#        'Z7Z7 Gris Cronos', 'Verde', 'Amarillo', '4M4M Naranja Calatea',
#        ')', '040 Blanco Classic', 'L5L5 Plata Florete', 'Light White',
#        'Naranja', 'A96 MineralweiÃ?', 'B4B4 Blanco Candy', 'POLAR WHITE',
#        'Z11 Negro', 'B22 British Racing Green', '8E8E Plata Brillante',
#        'Negro Brillante', '475 Saphirschwarz', 'Midnight Black',
#        'UD Clear White', 'GAN Plata Blade', 'B53 Sparkling Brown',
#        '2T2T Negro Profundo', 'Blanco Banquise', 'QPA$369 Blanco Glaciar',
#        '0E0E Negro Mitos', 'HW2 Deluxe White', '8E8E Plata RÃ©flex',
#        'Pure White', '487 Azul', '0Q0Q Blanco Puro', 'Blanco Glaciar',
#        '9P9P Blanco Candy', 'S7S7 Gris Magnetic', 'C10 Mediterranblau',
#        '676 Negro Nacarado', 'H7H7 Azul AtlÃ¡ntico', 'Dark Penta Metal',
#        '300 AlpinweiÃ?', 'Violeta / Lila', 'A83 Glaciersilber',
#        'FIRENZE RED', 'Gris', 'Fuji White', '668 Schwarz',
#        'M0F4 Gris Artense', 'C2M Island Blue', 'B39 Mineralgrau',
#        '149U Blanco Polar', 'Q4Q4 Gris Cuarzo', 'Azul Océano',
#        'F6F6 Gris Metal', 'A94 Midnight Black', 'X3X3 Gris Indy',
#        'GAZ Blanco Alpino', 'Blanco Alpino', 'D8D8 Rojo Flash',
#        '9M9M Rojo emociÃ³n', '73R Azul BÃ¡ltico', 'PN3GZ Blanco',
#        'C1N Sonnenstein', 'W1W1 Azul Lunar', 'pa10 Negro Grafito',
#        'met Pintura metalizada', '0A0A Azul Arrecife', 'B4B4 Blanco',
#        'A4D Artic White', 'Y1Y1 Rojo Tango', '614 Blanco',
#        'F6F6 Gris Rodium', 'M6N9 Blanco Nacarado', 'RPR Azul Cosmos',
#        '300 Alpinweib', '9P9P Blanco', 'A75 Melbourne Rot',
#        'C1D Misano Blau', 'B13 Cosmic Blue', 'Negro Phantom',
#        '475 Black Sapphire', 'P05 Gris MagnÃ©tico', 'Mineralweiss',
#        '589 Rojo JÃºpiter', '755 Gris Tenorita', '111 Rojo Passione',
#        'Rosa', 'L9A1 Azul ElÃ©ctrico/Techo Negro', 'B45 Estoril Blau',
#        'Rojo )', '040 Blanco', 'E1E1 Rojo Desire', '0E0E Negro Midnight',
#        '0C0C Gris Pirineos', '416 Carbonschwarz', '0C0C Gris MonzÃ³n',
#        '2Y2Y Blanco Glaciar', '149 Blanco Polar', 'L5L5 Plata Urban',
#        '7Y0E Azul Mistery  Techo Negro', '475 Sapphireschwarz', 'Schwarz',
#        'Tapicería en negro', '1F8 Gris Plata M',
#        'P03 Plata Perla Moondust', 'A52 Spacegrau', '7Y7Y Azul Mistery',
#        '6Y6Y Gris Daytona', '5K5K Gris Urano',
#        'C3B British Racing Green IV',
#        'GAB Platinum Graphite  / Electric Green', '890 Azul Cavansita',
#        '667U Azul denim', 'GNE Negro Brillante', 'SEOUL PEARL SILVER',
#        'Azul Ara', 'Piel Negra', 'Z1Z1 Gris magnesio', 'Plata',
#        'PSC Gris Metal', 'K5K5 Plata Tungsteno', 'A89 Imperialblau',
#        '3A3A Rojo Shiraz', 'B38 Midnight Blue', 'Negro Mica',
#        'QAB Blanco Perlado', 'Z1Z1 Gris Magnesio', 'Gris Vapor',
#        'Metallic Copper', '2Y2Y Blanco Nevada', 'P0WP Blanco Banquise',
#        'Gris Daytona', 'F9F9 Azul Caribe', 'Rojo Rubí', 'PHANTOM BLACK',
#        'Tapicería Mixta tela/símil cuero Harlekin Negro Jet',
#        'C1M Phytonicblau', 'Cosmo Blue',
#        '2YA2 Blanco Glaciar  - Arcos/techo Negro Brillante',
#        '5V5V Gris Manganeso', 'MOVL Gris Platino',
#        'Tapicería Negra y Marfil', 'Aurora Black', 'K3Y Celestial Silver',
#        'K1K1 Rojo Velvet', '0R0R Blanco Oryx', '7Y7Y Azul Mystery',
#        'A14 Mineralsilber', '230 Azul Indigolita', 'Negro Vesuvio',
#        'C24 Lapisluxury Blue', '0F0F Azul Lava', 'Rojo Incandescente',
#        'Gris Meteoro', '0Z0Z Turquesa Makena', 'QM1 Blanco Iceberg',
#        'Blanco Sonic', '650 Blanco Cirro', 'Blanco Ambient',
#        'C1C1 Amarillo Lima', 'OVD16 Blanco Marfil', '1AG Santorini Black',
#        'Y1Y1 Amarillo citrus', 'Clasificación medio ambiental B',
#        'D2D2 Azul UtopÃ\xada', '191 Negro Cosmos', '0E0E Negro Mito',
#        'Negro Onyx', 'A89 Imperialblau, efecto de brillo',
#        'PDM Gris Mineral', 'B15 Light White', 'Clear White + Inferno Red',
#        'F6F6 Gris Cuarzo', 'A89 Imperialblau con efecto brillante',
#        '1J2 Plata Sonic', 'Negro con bordados rojos', 'Negro Graphite',
#        'C3N Storm Bay', 'Gris Espacial', 'D69 Gris Platino',
#        'H1H1 Gris Manhattan', '425 Azul Italia', 'Q2Q2 Gris Tornado',
#        'Blanco Ibis', 'GBH Rojo PasiÃ³n', '850 Pepper White',
#        'Blanco Cirro', 'Silverstone', 'Gris  + Techo Negro',
#        'S6G Stone Gray', 'Azul Báltico', 'Y3Y White Sand',
#        'Gris Magnesio', '2D2D Azul Navarra', 'XN3 Moon Rock',
#        'M0VL Gris Platinum', 'C2K Melting Silver', '0Q0Q Blanco',
#        'pa02 Blanco', '', 'HNP Beige Duna', 'KNA Gris Cometa',
#        'GF6 Gris Acero', 'P6W Chalk White', 'Maroon Brown',
#        '73O Plata Perla Moondust', 'C08 Platinsilber', 'Gravity Blue',
#        'D17 Marron GlacÃ©', 'WD Cassa White', '1AD Mariana Black Premium',
#        '73F Negro Grafito', 'C37 Frozen Grey II', 'M8B Gris Magnetic',
#        'Tapicería Cairo gris oscuro/claro', 'Gris Mercurio',
#        'Gris Platino', 'PYW Polar White', '040 Negro', 'PA008 Lunar Grey',
#        'X-BLANCO', '7W7W Azul TritÃ³n', '4U4U MarrÃ³n Teca',
#        '1AB Corris Grey', 'Bronce Magnético', 'Deluxe White',
#        'Marrón Citrina', 'P09G Gris Hurricane', '735 Blanco',
#        'Tejido LOUNGE Negro/Gris', '1D Clear White',
#        'pa003 Stornoway Grey', 'pa13 Rojo Mars', 'M0KL Gris Amazonite',
#        'M0ZR Gris Aluminio', '9P9P Blanco candy', 'M09T Gris Garrigue',
#        'G3G3 Gris Nano', 'A76 Tiefseeblau', 'Onyx Negro',
#        'G6R Verde Esmeralda', 'Deep Cerulean Blue', 'B9B9 Azul Cosmos',
#        'A96 Mineralweiss', 'KAD Gris', 'U0U0 Azul Aviator',
#        'C1Z Bronce Vermont', '4EU Azul Marino', 'QPA$QNC Blanco Nacarado',
#        'Chalk White', '0A0A Azul Arrefice', 'Sophisto-grau brillant',
#        'P02 MagnÃ©tico', 'M6SM Blue Vertigo', 'designo rojo jacinto',
#        'Gris Acier', 'AA9 Infra Red', '890U Azul Cavansita',
#        'R3G Galaxy Grey', '9550 Azul MediterrÃ¡neo', 'Negro Cosmos',
#        'C07 Sparkling Storm efecto brillante', '09 Blanco',
#        'Z70E Gris Cronos /Techo Negro Mitos', 'FCF Rojo RubÃ\xad',
#        'M09V Negro Perla Nera', '687 Azul dipinto di blu', 'Gris Montaña',
#        '6T6T Amarillo CÃºrcuma', 'Alpinweib', 'U17 Gris Titanium',
#        '775 Plata Iridio', '9S9S Verde Camuflaje', '1G2 Gris meteoro',
#        'T9T9 Blanco Ibis', '5P5P Rojo Crimson', 'Arctic White Cle',
#        'Azul Scuba', 'Tapicería beige', 'A72 Kaschmirsilber',
#        'pa07 Rojo Mars', 'B41 Singapur Grau', 'pa03 Negro Grafito',
#        'ENGINE RED', 'Midnight Blue', '775 Plata iridio',
#        'NKA Phantom Black', 'RAH Sleek Silver', 'ZAR Steel Grey',
#        'CB7 Cosmo Blue', '0D0D Plata CuvÃ©e', '4P4P Azul OcÃ©ano',
#        'Blanco Puro', 'GB9 Negro Mineral', 'Negro Profundo',
#        'A89 Imperialblau, acabado brillo', 'Z3U Blue Lagoon',
#        'C36 Dravitgrau metalizado', 'pa04 Fuji White',
#        '268 Blanco Gelato', 'designo gris selenita magno', 'Titanium',
#        '9550 Azul MediterrÃ¡neo  - No disponible en Connect Blue',
#        'Negro Mágico efecto Perla', '326 Blanco', 'Sophistograu',
#        'Gris Moai', 'Aqua Green', 'M6SM Azul VÃ©rtigo',
#        '1AF Italian Racing Red', '72500 Rojo FusiÃ³n',
#        'E10E Rojo Desire  Techo Negro', 'C10 Mediterranean Blue',
#        'Negro Perla Nera', 'Charcoal', '761 Plata Polar', '))',
#        '1AP Kaikora Stone', 'EBZO Blanco', '851 Chili Red', 'Rojo Elixir',
#        'AUD Clear White  / Tan Orange', '73B Gris Magnetic',
#        'U3S Platinum Silver', 'RUNWAY RED', 'Gris Guard',
#        'GAR Negro Mica', 'Rojo Amore', 'Azul Brillante', 'B65 Jatoba',
#        'K2K2 Plata Pirita', 'Blanco  Techo Negro', '2Y2Y Blanco Luna',
#        'B40E Blanco  Techo Negro', "GXM Red 'n' Roll",
#        'F5F5 Naranja Eclipse', 'Rojo Pulse', '42B Deep Crystal Blue',
#        '996 Rojo Jacinto', 'POWP Blanco Banquise', 'Negro Shadow',
#        'Blanco Alfa', 'Black Sapphire', '1K Black Pearl',
#        'pa05 MagnÃ©tico', 'Glaciersilber', 'C2Y Bluestone',
#        'Gris Titanium', 'M0 Pintura metalizada',
#        'EAPO Bodypanels en rojo cadmio', 'GOP Caoba', 'Azul Naútico',
#        'TCW Creamy White', '354 Tintansilber', 'oPS Negro Granada',
#        'Rojo Júpiter (Previsiblem', '1Z1Z Negro MÃ¡gico',
#        'ULTIMATE BLACK', 'ZY2 Solid White', 'M0KU Dark Blue', 'Gris Hoja',
#        'GB0 Negro Mineral', 'Crystal White M.', 'Plata Brillante',
#        'JKM Rojo RubÃ\xad', 'Blanco Glaciar /Techo Negro Mitos',
#        'A90 Sophistograu', '070 Blanco Perlado', 'Gris Indy',
#        'L5L5 Plata Floret', 'GWD Plata Magnetic', '722 Perla',
#        'F4F4 Vesubio Gris', 'Blanco Nevada', '0C0C Gris MozÃ³n',
#        'Alpinweiß', 'Gris Himalaya', '11 Blue Spirit',
#        'MOUNTAINGRAU - MET.', 'H05 Gris Brillante', 'pa03 Gris Aluminio',
#        '1AA Fuji White', 'N9N9 Rojo Misano', 'Polar White',
#        'Y7Y7 Gris Dakota', 'AZUL CAVANSITA',
#        'Negro (AL38 Banqueta 2 plazas + Asiento basculante en 2Âª fila + Banqueta monobloque basculante 3 pl',
#        '2T Negro Jet', 'Gris Indium', '992 Gris selenita',
#        '197 Negro Obsidiana', '5J5J Gris Quantum', 'ROJO AMBAR',
#        '696 Negro noche', 'Blanco Oryx', 'N6N6 Azul Turbo',
#        '085 Blanco Sonic', '1J7 Titanium', '249 Blanco Gelato',
#        'Luxury negro', 'Gris Magnetic',
#        'N90E Rojo Misano /Techo Negro Mitos', 'A17 Havanna',
#        'MY3 Imperial Bronze', 'Negro Magnetita', 'S9S9 Azul Scuba',
#        '1R1R Gris Lava', 'Negro Mineral', '- Pintura No metalizada',
#        'W19 Blanco Polar', '"5CA 5CD 5DN 5DP 5DQ 5DR Pintura metalizada',
#        'GWH Gris Phantom', '2H Gris Volcano', 'GK2 Gris Mercurio',
#        'Blanco Candy', 'Rojo Júpiter', '695 Gris Oscuro',
#        'PN3JV Azul BÃ¡ltico', '8E8E Plata Reflex', 'GWJ Azul OcÃ©ano',
#        '300 Alpinweiss', 'Azul Millenium', 'Rojo Tokio',
#        '197 Negro obsidiana', 'Blanco Nacarado', 'Signal Red',
#        'Blanco Antarctique', 'Gris Diamante', '792 Plata Paladio',
#        'C2S Jucarobeige', '1AM Dark Sapphire', 'P0P0 MarrÃ³n Roble',
#        'STAR DUST', 'FRD Track Red', 'Mineral', 'Blanco Frost',
#        '41W Jet Black', '2T2T Deep Black', 'R3U Ara Blue',
#        'X3X3 Gris Indium', 'Gris Platino  techo Negro Onyx',
#        'L8L8 Negro Cosmos', 'B17 Bright Yellow', 'Rojo Tornado',
#        '240 Azul Loto', 'GG7 Rojo RubÃ\xad', 'SWP Snow Pearl White',
#        '417 DARK BLUE PEARL', 'T1T1 Amarillo Sunflowers',
#        'U3U3 MarrÃ³n Nuez', '79U Rojo Magma', 'L8L8 Negro Phantom',
#        'H7H7 Azul Atlantic', '4B4B Rojo Cereza', 'KM0', 'Azul Calvi',
#        'Night Blue', 'NAJ Rojo FusiÃ³n', '3U5 Rojo EmociÃ³n',
#        'H8G Dark Penta Metal', '787 Gris MontaÃ±a', 'pa08 Verde Guard',
#        'P0XY Negro Onyx', 'PINTURA METALIZADA - PLAT', '1J4 Plata',
#        'QPA$D69 Gris Platino', 'Gris Aluminio', 'Designo Rojo Jacinto',
#        '9NH Blanco', 'TKG Shadow Grey', 'A61 Karmesinrot', 'Gris Haria',
#        'pa06 Negro Perla', '696 Negro Noche', 'VINILO',
#        '2TSL Negro Profundo  / Capota Negra', 'pa10 Metalicioso',
#        'D16 Blanco Marfil', 'C31 Portimao Blau', 'Azul Lunar',
#        '0Y0Y MarrÃ³n Java', '2Y0E Blanco Glaciar /Techo Negro Mitos',
#        'ABP Aurora Black', 'Azul Navarra', '4N4N Gris Oolong',
#        'KNG Gris Casiopea', 'Rojo Aultimate', 'Platinum Graphite',
#        '8X8 Azul Orion', 'B3L Blue Flame', 'GAR Carbon Flash',
#        '9P9P Blanco Bila', 'pa08 Blanco', 'Runway Red', 'Gris Cuarzo',
#        'Plata Mojave', 'Blanco Perlado', 'Gris Mozón',
#        'pa03 Gris Graphito', '5U0E Azul Firmamento /Techo Negro Mitos',
#        'Santorini Black', '268 Blanco Bossa Nova', 'Blanco Classic',
#        'Gris montaña', 'Azul Midnight', 'PULSE RED', 'PBSB Negro',
#        '1011 Rojo Vivo', 'pa05 Fuji White', 'M0F4 Gris Acero',
#        'Negro Habana', 'BIYPC Blanco Albatros  + techo negro',
#        '426 Plata', '9X9X Beige Dakar', 'Plata Iridio',
#        '2Y0E Blanco Nevada  Techo Negro', 'M0V7 Rojo Tourmalin',
#        '9M9M Rojo', 'Tapicería Life negra', 'Kairo Negra',
#        '1AA Polaris White', 'FUJI WHITE', 'A92 Orionsilber',
#        '2T2T Gris Niebla', 'B50 Sakhir Orange', 'Gris Artense',
#        'Jet Black', '0J0J MarrÃ³n Magnetic', '1F7 Plata', 'Gris Platinum',
#        'D14 Azul Tanzanite', 'M09P Gris Shark', 'Sonic Silver',
#        '416 Carbonschwartz', '0C0C Gis MonzÃ³n', 'M05L Azul Montebello',
#        'IM Titanium Silver', 'GR5 Gris Espacial', 'Plata Perla Moondust',
#        'Blanco Marfil', 'Gris Tenorita', 'Breathing Blue',
#        '42A Meteor Gray', 'Newport Blue', '019 Negro', 'PLATINIUM SILVER',
#        'Bodypanels en steel blue', '796 MarrÃ³n Citrina',
#        '9C9C Rojo Granate', 'I4I4 Azul Apolo', '9S9S Dark Camouflage',
#        'Plata Réflex', '268a Blanco Gelato', 'designo blanco diamante B',
#        'Azul Noche', 'Gris Platinium', 'Negro Pulsar', 'Gris Phantom',
#        'pa19 Gris MagnÃ©tico', 'MZH Phantom Black', '1BC Scotia Grey',
#        'B4F5 Blanco  Techo Naranja', '5Z5Z Azul Ravenna', 'Plata Blade',
#        'pa12 Orkney Grey', 'JHR Engine Red', 'pa01 Blanco Banquise',
#        'X10 Tansanitblau', 'B71 Moonwalk Grey', 'Azul Cosmos',
#        '8T8T Rojo Fuego', 'GWJ Azul Oceano', 'SANTORINI BLACK',
#        'NPF Rojo CarmÃ\xadn', 'Quantum Yellow', 'Grafito', 'MICRON GREY',
#        '8Q8Q Naranja Coral', 'Blanco Alpine', 'PNZAT0 - Negro Shadow',
#        'pa03 Blanco', '354 Titansilber', 'D5U Sand Track', 'SLEEK SILVER',
#        '319 Gris antracita', 'U8 Oro Metalizado', 'G0A Rojo Magma',
#        'pa01 Negro Ã?bano', '209 Negro Azabache', 'PN4HS Plata Solar',
#        'Tela Negra', '7B7B Gris Espejo', 'G2G2 Rojo Tornado',
#        'Rojo Pasión', 'Y3Y Brown Sand', 'pa09 Negro Grafito',
#        'A34 Arktis', 'pa07 MarrÃ³n Brisbane', 'K6K6 Azul Ara',
#        'A1A1 Negro', '1H5 Gris Manhattan', 'NEGRO OBSIDIANA',
#        'White Sand', 'B14 True Blue', '5T5T Gris SatÃ©n',
#        '25D Snowflake White Pear', 'M0/P0 Pintura metalizada/opaca',
#        'Blanco Polar Ice', 'A35 Monacoblau',
#        '1X0E Gris Flecha /Techo Negro Mitos', '1G3 Gris Grafito',
#        'Plata Perla', 'Verde Eléctrico Ultimate', 'K8K8 Plata Claro',
#        'Gris Grafito', 'B0B0 Gris DelfÃ\xadn',
#        'G3A2 Nano Grey  - Arcos/techo Negro Brillante',
#        '5CC,5CE,5DP,5DT Pintura exterior', 'P5P5 Plata Hielo',
#        'Galaxy Grey', '2KR Bi-tono Blanco Perlado/Negro',
#        'Phoenix Silver', '990 MarrÃ³n Oriente', 'Saphirschwarz',
#        'EN4U Tridion Negro', 'Negro Oscuro', '73H Azul Impact',
#        'C4F Arctic Race Blue metalizado', 'TERQH Azul Rayo',
#        'PSW Polar White', 'Azul Chrome', 'W13 Blanco Silky', 'Rojo Lucid',
#        '6K6K Rojo Atardecer', 'Naranja Cuántico', '8H8H Azul Aguamarina',
#        'B23 Spice Orange', '888 Azul Venecia', 'Lunar Silver',
#        '08 Ice Blue', 'Bi-tono Rojo Emoción', 'Tapicería cuero sintético',
#        '1J1J Gris Amatista', 'Naranja Eclipse  Techo Gris',
#        '1AF Firenze red', 'A4D Arctic White Cle', 'Azul Chromet',
#        'GRIS/PLATA', 'M0EG Azul Magnetic', 'R6R6 Blanco Campanella',
#        'Bodypanels en gris titani', 'P0Y2 Rojo Scarlet', 'Gunmetal Grey',
#        'Clear White', 'Beige Capuccino', 'GDX Azul ConstelaciÃ³n',
#        'Negro Diamante', 'pa04 Lunar Grey',
#        '4MA1 Naranja Calatea /Techo Negro', '1AS Bluefire',
#        'M5M5 MarrÃ³n Beluga', 'D5D5 Azul PacÃ\xadfico',
#        '4Q4Q MarrÃ³n Dakar', 'Plata Reflex', 'Blanco Polar',
#        'Olivine Grey', 'pa10 Negro Grafito Panther', 'Negro Amethyst',
#        'pa09 Negro Perla', 'CLEAN SLATE', 'Negro mágico efecto perla',
#        'Blanco Brilliant White', 'C1P Galvanic Gold', '3T3 Rojo Tokio',
#        'X5X5 Gis Meteorito', 'Blanco Lásser', 'WHITE SAND',
#        '46G Machine Gray', 'R6R6 Gris Graephene', 'CAVANSITA',
#        '149 Blanco polar', 'Sparkling Bronze', 'NNP Rojo Deseo',
#        'D16 Marfil Delhi', 'Gris Shark', 'P01 Blanco',
#        'N9H1 Rojo Misano /Techo Gris Manhattan', '1E0 Gris oscuro',
#        '963 Gris Indio', 'Azul Mediterráneo', '498 Azul Caspio',
#        'Vinilado Gris Mate', '5CL Bicolor Gris moda', '02 Plata Perla',
#        'designo gris magnp', 'QPA$KPN Gris Titanium', 'Ámbar',
#        '10 Gris Techno', 'C16 Long Beach Blau', 'BLANCO', 'Blanco Jade',
#        'A4A4 Gris Cocou', 'pa07 Negro Grafito', '8X5 Azul Oceano',
#        'PINTURA ESTANDAR - ROJO J', 'C26 Magellangrau',
#        '8E8E Gris Reflex', 'NER Polaris White', 'Azul Rayo', 'Gris Acero',
#        '4K4K Beige Capuccino', 'Mineralgrau', 'Azul Magnetic',
#        'Azul Mistery  Techo Negro', '992 Gris Selenita',
#        'Azul Mediterráneo  - No disponible en Connect Blue',
#        'CHALK WHITE', '5CA Blanco Alpine', 'Gris Urano'], dtype=object)

# %%
df_limpio2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 41258 entries, 0 to 41257
# Data columns (total 23 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   make              41258 non-null  object
#  1   model             41258 non-null  object
#  2   version           41258 non-null  object
#  3   price             41258 non-null  int64
#  4   fuel              41258 non-null  object
#  5   year              41258 non-null  float64
#  6   kms               41258 non-null  int64
#  7   power             41258 non-null  float64
#  8   doors             41258 non-null  int64
#  9   shift             41258 non-null  object
#  10  color             41258 non-null  object
#  11  photos            41258 non-null  int64
#  12  is_professional   41258 non-null  bool
#  13  province          41258 non-null  object
#  14  make_number       41258 non-null  int64
#  15  model_number      41258 non-null  int64
#  16  model_numberdos   41258 non-null  int64
#  17  make_model_ref    41258 non-null  int64
#  18  combustible_int   41258 non-null  int64
#  19  provincia_numero  41258 non-null  int32
#  20  cambio_int        41258 non-null  int64
#  21  prof_int          41258 non-null  int32
#  22  color_limpio      41258 non-null  object
# dtypes: bool(1), float64(2), int32(2), int64(10), object(8)
# memory usage: 6.6+ MB

# %%
label_encoder = LabelEncoder()

df_limpio2['color_numero'] = label_encoder.fit_transform(df_limpio2['color_limpio'])

# %%
plt.figure(figsize=(10, 10))
sns.boxplot(x=df_limpio2['price'])
plt.title('Boxplot de la columna "kms"')
plt.xlabel('Kilómetros')
plt.show()

# %%
df_mas_100k_euros = df_limpio2[df_limpio2['price'] > 99999]

# %%
df_mas_100k_euros
# Out:
#                 make     model  \
# 161          PORSCHE       911
# 181          PORSCHE       911
# 359          PORSCHE   Cayenne
# 370    MERCEDES-BENZ   Clase G
# 549          PORSCHE     Macan
# ...              ...       ...
# 40265  MERCEDES-BENZ   Clase S
# 40575        PORSCHE  Panamera
# 40609        PORSCHE       911
# 40765        PORSCHE   Cayenne
# 41049           AUDI        A6
#
#                                                  version   price      fuel  \
# 161                            PORSCHE 911 Speedster 2p.  410000  Gasolina
# 181                              PORSCHE 911 CARRERA 2p.  117999  Gasolina
# 359                              PORSCHE Cayenne GTS 5p.  135900  Gasolina
# 370           MERCEDES-BENZ Clase G MercedesAMG G 63 5p.  108300  Gasolina
# 549                            PORSCHE Macan Macan S 5p.  101900  Gasolina
# ...                                                  ...     ...       ...
# 40265  MERCEDES-BENZ Clase S S 500 4MATIC EQ Boost Co...  168900  Gasolina
# 40575           PORSCHE Panamera Turbo Sport Turismo 5p.  145000  Gasolina
# 40609                           PORSCHE 911 Targa 4S 2p.  119900  Gasolina
# 40765                            PORSCHE Cayenne GTS 5p.  134900  Gasolina
# 41049                AUDI A6 RS 6 Avant TFSI quattro 5p.  170000  Gasolina
#
#          year    kms  power  doors       shift  ... make_number  model_number  \
# 161    2019.0    150  510.0      2      Manual  ...          67           857
# 181    2020.0   5999  385.0      2  Automático  ...          67           857
# 359    2020.0   6800  460.0      5  Automático  ...          67           797
# 370    2018.0  43000  571.0      5  Automático  ...          56           863
# 549    2021.0     10  354.0      5  Automático  ...          67           825
# ...       ...    ...    ...    ...         ...  ...         ...           ...
# 40265  2021.0     10  435.0      4  Automático  ...          56           749
# 40575  2018.0   8000  550.0      5  Automático  ...          67           836
# 40609  2016.0  37000  420.0      2  Automático  ...          67           857
# 40765  2020.0   6600  460.0      5  Automático  ...          67           797
# 41049  2020.0    216  600.0      5  Automático  ...          49           672
#
#        model_numberdos make_model_ref  combustible_int  provincia_numero  \
# 161                 10           6710                1                17
# 181                 10           6710                1                17
# 359                  5           6705                1                 7
# 370                 49           5649                1                45
# 549                  7           6707                1                 7
# ...                ...            ...              ...               ...
# 40265               31           5631                1                 7
# 40575                8           6708                1                45
# 40609               10           6710                1                 7
# 40765                5           6705                1                 7
# 41049               16           4916                1                42
#
#        cambio_int  prof_int  color_limpio  color_numero
# 161             0         1  Gris / Plata           412
# 181             1         1         Negro           526
# 359             1         1        Blanco           282
# 370             1         1         Negro           526
# 549             1         1         Negro           526
# ...           ...       ...           ...           ...
# 40265           1         1         Negro           526
# 40575           1         1  Gris / Plata           412
# 40609           1         1         Negro           526
# 40765           1         1         Negro           526
# 41049           1         1  Gris / Plata           412
#
# [194 rows x 24 columns]

# %%
df_mas_500k_kms = df_limpio2[df_limpio2['kms'] < 10000]

# %%
df_mas_500k_kms
# Out:
#              make        model  \
# 13          SKODA      Octavia
# 18            BMW      Serie 1
# 30        PEUGEOT   508 Hybrid
# 32            KIA        XCeed
# 37        PEUGEOT       Rifter
# ...           ...          ...
# 41201        OPEL  Zafira Life
# 41215        AUDI           A3
# 41232  VOLKSWAGEN         Golf
# 41244        SEAT        Arona
# 41250        JEEP      Compass
#
#                                                  version  price  \
# 13         SKODA Octavia 1.0 TSI 85KW 115CV Ambition 5p.  13990
# 18                                  BMW Serie 1 116d 5p.  28900
# 30           PEUGEOT 508 Hybrid SW GT Line 225 eEAT8 5p.  37000
# 32        KIA XCeed 1.6 GDi PHEV 104kW 141CV eMotion 5p.  32300
# 37           PEUGEOT Rifter GT Standard BlueHDi 96kW 5p.  26995
# ...                                                  ...    ...
# 41201  OPEL Zafira Life 1.5 Diesel 88kW 120CV M Selec...  30900
# 41215  AUDI A3 Sportback S line 40 etron 150kW S tron...  34000
# 41232  VOLKSWAGEN Golf Business 1.6 TDI 85kW 115CV DS...  19987
# 41244      SEAT Arona 1.0 TSI 70kW 95CV Style Go Eco 5p.  18646
# 41250          JEEP Compass 1.4 Mair 103kW Sport 4x2 5p.  21900
#
#                      fuel    year   kms  power  doors       shift  ...  \
# 13               Gasolina  2019.0  7591  115.0      5      Manual  ...
# 18                 Diésel  2020.0  5000  116.0      5  Automático  ...
# 30     Híbrido enchufable  2020.0  1200  225.0      5  Automático  ...
# 32     Híbrido enchufable  2021.0  2800  141.0      5      Manual  ...
# 37                 Diésel  2021.0     1  130.0      5      Manual  ...
# ...                   ...     ...   ...    ...    ...         ...  ...
# 41201              Diésel  2020.0     1  120.0      5      Manual  ...
# 41215  Híbrido enchufable  2020.0    65  204.0      5  Automático  ...
# 41232              Diésel  2019.0  8112  115.0      5  Automático  ...
# 41244            Gasolina  2020.0     0   95.0      5      Manual  ...
# 41250            Gasolina  2020.0  5000  140.0      5      Manual  ...
#
#       make_number  model_number  model_numberdos make_model_ref  \
# 13             34           488                9           3409
# 18             50           515                3           5003
# 30             29           766               42           2942
# 32             40           680               24           4024
# 37             29           605               37           2937
# ...           ...           ...              ...            ...
# 41201          23           768               34           2334
# 41215          49           542               10           4910
# 41232          38           471               17           3817
# 41244          27           562               13           2713
# 41250          53           688                6           5306
#
#        combustible_int  provincia_numero  cambio_int  prof_int  \
# 13                   1                29           0         1
# 18                   0                 7           1         1
# 30                   5                36           1         1
# 32                   5                31           0         1
# 37                   0                49           0         1
# ...                ...               ...         ...       ...
# 41201                0                 7           0         1
# 41215                5                 2           1         1
# 41232                0                45           1         1
# 41244                1                29           0         1
# 41250                1                33           0         1
#
#          color_limpio  color_numero
# 13       Gris / Plata           412
# 18       Gris / Plata           412
# 30             Blanco           282
# 32        Cassa White           340
# 37       Gris / Plata           412
# ...               ...           ...
# 41201    Gris / Plata           412
# 41215          Blanco           282
# 41232  X3X3 Gris Indy           681
# 41244    Gris / Plata           412
# 41250    Gris / Plata           412
#
# [5485 rows x 24 columns]

# %%
#df_limpio2['is_premium'] = df_limpio2['price'] > 42000

# %%
#df_limpio2['prem_int'] = df_limpio2['is_premium'].astype(int)
#df_limpio2.head()

# %%
df_limpio2['km_0'] = df_limpio2['kms'] < 10000

# %%
df_limpio2['km_0_int'] = df_limpio2['km_0'].astype(int)
df_limpio2.head()
# Out:
#          make            model  \
# 0     CITROEN               C1
# 1        FORD  Transit Connect
# 2  VOLKSWAGEN        Caravelle
# 3        FORD          Transit
# 4     PEUGEOT             3008
#
#                                              version  price      fuel    year  \
# 0             CITROEN C1 PureTech 60KW 82CV Feel 5p.   6200  Gasolina  2017.0
# 1  FORD Transit Connect Van 1.5 TDCi 100cv Ambien...   7851    Diésel  2016.0
# 2  VOLKSWAGEN Caravelle Largo 2.0 TDI 140 Comfort...  19426    Diésel  2014.0
# 3  FORD Transit 350 96kW L4 Ambiente Propulsion T...  22850    Diésel  2017.0
# 4         PEUGEOT 3008 Style 1.2 PureTech 130 SS 5p.  11490  Gasolina  2016.0
#
#       kms  power  doors   shift  ... model_numberdos  make_model_ref  \
# 0   50071   82.0      5  Manual  ...              22            2022
# 1  103000  100.0      4  Manual  ...              17            2417
# 2  120000  140.0      4  Manual  ...              31            3831
# 3  107000  130.0      2  Manual  ...              23            2423
# 4   78665  130.0      5  Manual  ...              38            2938
#
#    combustible_int provincia_numero  cambio_int  prof_int  color_limpio  \
# 0                1               42           0         1        Blanco
# 1                0                7           0         1        Blanco
# 2                0               33           0         1        Blanco
# 3                0               39           0         1        Blanco
# 4                1               29           0         1        Blanco
#
#    color_numero   km_0  km_0_int
# 0           282  False         0
# 1           282  False         0
# 2           282  False         0
# 3           282  False         0
# 4           282  False         0
#
# [5 rows x 26 columns]

# %%
percentil_85 = df_limpio2['price'].quantile(0.85)

# Dividir el dataframe en dos partes
df_limpio3 = df_limpio2[df_limpio2['price'] <= percentil_85]
df_premium = df_limpio2[df_limpio2['price'] > percentil_85]

# Verificar la cantidad de registros en cada dataframe
print("Registros en df_bajo_percentil_85:", len(df_limpio3))
print("Registros en df_alto_percentil_85:", len(df_premium))

# Mostrar los primeros registros de cada dataframe
print("Primeros registros de df_bajo_percentil_85:")
print(df_limpio3.head())

print("Primeros registros de df_alto_percentil_85:")
print(df_premium.head())
# Out:
# Registros en df_bajo_percentil_85: 35069
# Registros en df_alto_percentil_85: 6189
# Primeros registros de df_bajo_percentil_85:
#          make            model  \
# 0     CITROEN               C1
# 1        FORD  Transit Connect
# 2  VOLKSWAGEN        Caravelle
# 3        FORD          Transit
# 4     PEUGEOT             3008
#
#                                              version  price      fuel    year  \
# 0             CITROEN C1 PureTech 60KW 82CV Feel 5p.   6200  Gasolina  2017.0
# 1  FORD Transit Connect Van 1.5 TDCi 100cv Ambien...   7851    Diésel  2016.0
# 2  VOLKSWAGEN Caravelle Largo 2.0 TDI 140 Comfort...  19426    Diésel  2014.0
# 3  FORD Transit 350 96kW L4 Ambiente Propulsion T...  22850    Diésel  2017.0
# 4         PEUGEOT 3008 Style 1.2 PureTech 130 SS 5p.  11490  Gasolina  2016.0
#
#       kms  power  doors   shift  ... model_numberdos  make_model_ref  \
# 0   50071   82.0      5  Manual  ...              22            2022
# 1  103000  100.0      4  Manual  ...              17            2417
# 2  120000  140.0      4  Manual  ...              31            3831
# 3  107000  130.0      2  Manual  ...              23            2423
# 4   78665  130.0      5  Manual  ...              38            2938
#
#    combustible_int provincia_numero  cambio_int  prof_int  color_limpio  \
# 0                1               42           0         1        Blanco
# 1                0                7           0         1        Blanco
# 2                0               33           0         1        Blanco
# 3                0               39           0         1        Blanco
# 4                1               29           0         1        Blanco
#
#    color_numero   km_0  km_0_int
# 0           282  False         0
# 1           282  False         0
# 2           282  False         0
# 3           282  False         0
# 4           282  False         0
#
# [5 rows x 26 columns]
# Primeros registros de df_alto_percentil_85:
#           make            model  \
# 5   LAND-ROVER  Discovery Sport
# 18         BMW          Serie 1
# 26        FORD            S-MAX
# 30     PEUGEOT       508 Hybrid
# 32         KIA            XCeed
#
#                                               version  price  \
# 5   LAND-ROVER Discovery Sport 2.0L TD4 110kW 150C...  28500
# 18                               BMW Serie 1 116d 5p.  28900
# 26  FORD SMAX 2.0 TDCi Panther 110kW Titanium Pow 5p.  29300
# 30        PEUGEOT 508 Hybrid SW GT Line 225 eEAT8 5p.  37000
# 32     KIA XCeed 1.6 GDi PHEV 104kW 141CV eMotion 5p.  32300
#
#                   fuel    year    kms  power  doors       shift  ...  \
# 5               Diésel  2017.0  36238  150.0      5  Automático  ...
# 18              Diésel  2020.0   5000  116.0      5  Automático  ...
# 26              Diésel  2019.0  11936  150.0      5  Automático  ...
# 30  Híbrido enchufable  2020.0   1200  225.0      5  Automático  ...
# 32  Híbrido enchufable  2021.0   2800  141.0      5      Manual  ...
#
#    model_numberdos  make_model_ref  combustible_int provincia_numero  \
# 5                5            6205                0                6
# 18               3            5003                0                7
# 26              24            2424                0               28
# 30              42            2942                5               36
# 32              24            4024                5               31
#
#     cambio_int  prof_int  color_limpio  color_numero   km_0  km_0_int
# 5            1         1        Blanco           282  False         0
# 18           1         1  Gris / Plata           412   True         1
# 26           1         1         Negro           526  False         0
# 30           1         1        Blanco           282   True         1
# 32           0         1   Cassa White           340   True         1
#
# [5 rows x 26 columns]

# %%
#df_limpio3.to_csv('df_limpioper85.csv', index=False)

# %%
#df_premium.to_csv('df_premiumper85.csv', index=False)

# %%
df_limpio3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 35069 entries, 0 to 41257
# Data columns (total 26 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   make              35069 non-null  object
#  1   model             35069 non-null  object
#  2   version           35069 non-null  object
#  3   price             35069 non-null  int64
#  4   fuel              35069 non-null  object
#  5   year              35069 non-null  float64
#  6   kms               35069 non-null  int64
#  7   power             35069 non-null  float64
#  8   doors             35069 non-null  int64
#  9   shift             35069 non-null  object
#  10  color             35069 non-null  object
#  11  photos            35069 non-null  int64
#  12  is_professional   35069 non-null  bool
#  13  province          35069 non-null  object
#  14  make_number       35069 non-null  int64
#  15  model_number      35069 non-null  int64
#  16  model_numberdos   35069 non-null  int64
#  17  make_model_ref    35069 non-null  int64
#  18  combustible_int   35069 non-null  int64
#  19  provincia_numero  35069 non-null  int32
#  20  cambio_int        35069 non-null  int64
#  21  prof_int          35069 non-null  int32
#  22  color_limpio      35069 non-null  object
#  23  color_numero      35069 non-null  int32
#  24  km_0              35069 non-null  bool
#  25  km_0_int          35069 non-null  int32
# dtypes: bool(2), float64(2), int32(4), int64(10), object(8)
# memory usage: 6.2+ MB

# %%
df_limpio3.describe()
# Out:
#               price          year           kms         power         doors  \
# count  35069.000000  35069.000000  3.506900e+04  35069.000000  35069.000000
# mean   12592.136417   2013.202857  1.081070e+05    130.215204      4.536656
# std     6801.930706      5.844587  8.336913e+04     45.468258      0.827036
# min      300.000000   1980.000000  0.000000e+00     29.000000      2.000000
# 25%     7000.000000   2009.000000  4.267800e+04    102.000000      4.000000
# 50%    12000.000000   2015.000000  9.615900e+04    120.000000      5.000000
# 75%    17890.000000   2018.000000  1.573460e+05    150.000000      5.000000
# max    27150.000000   2022.000000  2.650000e+06    550.000000      5.000000
#
#              photos   make_number  model_number  model_numberdos  \
# count  35069.000000  35069.000000  35069.000000     35069.000000
# mean      17.983632     34.286492    459.408423        17.340700
# std       11.836204     12.442617    148.478491         9.777511
# min        0.000000      1.000000      1.000000         1.000000
# 25%        9.000000     23.000000    357.000000        10.000000
# 50%       15.000000     33.000000    471.000000        17.000000
# 75%       25.000000     46.000000    561.000000        25.000000
# max       54.000000     67.000000    863.000000        49.000000
#
#        make_model_ref  combustible_int  provincia_numero    cambio_int  \
# count    35069.000000     35069.000000      35069.000000  35069.000000
# mean      3445.989934         0.523881         25.465311      0.248966
# std       1241.190883         0.950456         14.814573      0.432420
# min        101.000000         0.000000          0.000000      0.000000
# 25%       2332.000000         0.000000          8.000000      0.000000
# 50%       3321.000000         0.000000         29.000000      0.000000
# 75%       4604.000000         1.000000         38.000000      0.000000
# max       6710.000000         6.000000         51.000000      1.000000
#
#            prof_int  color_numero      km_0_int
# count  35069.000000  35069.000000  35069.000000
# mean       0.759702    386.966609      0.092019
# std        0.427270    130.790271      0.289056
# min        0.000000      0.000000      0.000000
# 25%        1.000000    282.000000      0.000000
# 50%        1.000000    412.000000      0.000000
# 75%        1.000000    526.000000      0.000000
# max        1.000000    729.000000      1.000000

# %%
plt.figure(figsize=(10, 10))
sns.boxplot(x=df_limpio3['price'])
plt.title('Boxplot de precio con el percentil 85"')
plt.xlabel('Precio')
plt.show()

# %%
df_limpio2.describe()
# Out:
#                price          year           kms         power         doors  \
# count   41258.000000  41258.000000  4.125800e+04  41258.000000  41258.000000
# mean    17380.114184   2013.863929  9.789206e+04    146.541422      4.524117
# std     17178.194696      5.762015  8.261140e+04     71.366799      0.853533
# min       300.000000   1980.000000  0.000000e+00     29.000000      2.000000
# 25%      7999.000000   2010.000000  2.957225e+04    109.000000      4.000000
# 50%     13999.000000   2016.000000  8.500000e+04    130.000000      5.000000
# 75%     21700.000000   2018.000000  1.460000e+05    163.000000      5.000000
# max    549900.000000   2022.000000  2.650000e+06    800.000000      5.000000
#
#              photos   make_number  model_number  model_numberdos  \
# count  41258.000000  41258.000000  41258.000000     41258.000000
# mean      18.635222     36.596369    495.114523        17.671555
# std       12.180688     13.469030    166.306915        10.119053
# min        0.000000      1.000000      1.000000         1.000000
# 25%        9.000000     24.000000    378.000000        10.000000
# 50%       16.000000     37.000000    499.000000        17.000000
# 75%       26.000000     49.000000    621.000000        26.000000
# max       54.000000     72.000000    881.000000        51.000000
#
#        make_model_ref  combustible_int  provincia_numero    cambio_int  \
# count    41258.000000     41258.000000      41258.000000  41258.000000
# mean      3677.308474         0.603253         25.434243      0.340079
# std       1344.297339         1.116161         14.814466      0.473741
# min        101.000000         0.000000          0.000000      0.000000
# 25%       2418.000000         0.000000          8.000000      0.000000
# 50%       3719.000000         0.000000         29.000000      0.000000
# 75%       4930.000000         1.000000         37.000000      1.000000
# max       7203.000000         6.000000         51.000000      1.000000
#
#            prof_int  color_numero      km_0_int
# count  41258.000000  41258.000000  41258.000000
# mean       0.782151    386.582529      0.132944
# std        0.412789    131.871775      0.339518
# min        0.000000      0.000000      0.000000
# 25%        1.000000    282.000000      0.000000
# 50%        1.000000    412.000000      0.000000
# 75%        1.000000    526.000000      0.000000
# max        1.000000    730.000000      1.000000

# %%
plt.figure(figsize=(12,5))
sns.heatmap(df_limpio2.corr(numeric_only=True), cmap='coolwarm', vmin=-1,annot=True)
# Out:
# <Axes: >

# %%
df_limpio2.columns
# Out:
# Index(['make', 'model', 'version', 'price', 'fuel', 'year', 'kms', 'power',
#        'doors', 'shift', 'color', 'photos', 'is_professional', 'province',
#        'make_number', 'model_number', 'model_numberdos', 'make_model_ref',
#        'combustible_int', 'provincia_numero', 'cambio_int', 'prof_int',
#        'color_limpio', 'color_numero', 'km_0', 'km_0_int'],
#       dtype='object')

# %%
plt.figure(figsize=(12,5))
sns.heatmap(df_limpio3.corr(numeric_only=True), cmap='coolwarm', vmin=-1,annot=True)
# Out:
# <Axes: >

# %%
x= df_limpio3[['year', 'kms', 'power','make_number','model_number','cambio_int', 'prof_int']]

y= df_limpio3["price"]

# %%
X_train, X_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=42)

# %%
print(X_train.shape)
print(X_test.shape)
print(y_train.shape)
print(y_test.shape)
# Out:
# (28055, 7)
# (7014, 7)
# (28055,)
# (7014,)

# %%
lr = LinearRegression()

lr.fit(X_train, y_train)

y_pred = lr.predict(X_test)


maelr = mean_absolute_error(y_test, y_pred)
print('R2 score', r2_score(y_test, y_pred))
print('MAE', maelr)
print('MSE', mean_squared_error(y_test, y_pred))
print('RMSE', mean_squared_error(y_test, y_pred)**(1/2))
# Out:
# R2 score 0.79590768712409
# MAE 2388.8577241321036
# MSE 9645172.286435485
# RMSE 3105.6677681998576

# %%
'''
import pickle

with open('linear_regression_85.pkl', 'wb') as file:
    pickle.dump(lr, file)
'''

# %%
from sklearn.linear_model import Ridge, Lasso

ridge = Ridge()
lasso = Lasso()

ridge.fit(X_train, y_train)
lasso.fit(X_train, y_train)

ridge_mae = mean_absolute_error(y_test, ridge.predict(X_test))
lasso_mae = mean_absolute_error(y_test, lasso.predict(X_test))
print(ridge_mae)
print(lasso_mae)
# Out:
# 2388.859275557932
# 2388.835969788162

# %%
'''
with open('ridge_85.pkl', 'wb') as file:
    pickle.dump(ridge, file)
'''

# %%
'''
with open('lasso_85.pkl', 'wb') as file:
    pickle.dump(lasso, file)
'''

# %%
from sklearn.ensemble import RandomForestRegressor

rf = RandomForestRegressor()
rf.fit(X_train, y_train)
rf_mae = mean_absolute_error(y_test, rf.predict(X_test))

# %%
print(rf_mae)
# Out:
# 1340.9894536134007

# %%
#with open('RFR_85.pkl', 'wb') as file:
#    pickle.dump(rf, file)

# %%
from xgboost import XGBRegressor


xgb = XGBRegressor()
xgb.fit(X_train, y_train)
y_pred = xgb.predict(X_test)
xgb_mae = mean_absolute_error(y_test, y_pred)

# %%
print(xgb_mae)
# Out:
# 1333.3144699218506

# %%
#with open('xgb_85.pkl', 'wb') as file:
#    pickle.dump(xgb, file)

# %%
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout
# Estandarizar las características
scaler = StandardScaler()
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)

# Definir la arquitectura del modelo
model = Sequential()
model.add(Dense(64, input_dim=X_train.shape[1], activation='relu'))
model.add(Dropout(0.2))
model.add(Dense(32, activation='relu'))
model.add(Dense(1))  # Salida única para la regresión

# Compilar el modelo
model.compile(optimizer='adam', loss='mean_absolute_error')

# Entrenar el modelo
history = model.fit(X_train, y_train, epochs=100, batch_size=32, validation_split=0.2)

# Evaluar el modelo
nn_mae = model.evaluate(X_test, y_test)
print(f'MAE del modelo de red neuronal: {nn_mae}')
# Out:
# Epoch 1/100
# c:\Users\apere\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\layers\core\dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 702/702 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - loss: 12176.9766 - val_loss: 7146.0103
# Epoch 2/100
# 702/702 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 5115.4985 - val_loss: 2528.2776
# Epoch 3/100
# 702/702 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 2590.4651 - val_loss: 2074.2930
# Epoch 4/100
# 702/702 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 2184.4626 - val_loss: 1898.6163
# Epoch 5/100
# 702/702 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 2035.5619 - val_loss: 1830.9127
# Epoch 6/100
# 702/702 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 1982.6982 - val_loss: 1806.7279
# Epoch 7/100
# 702/702 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 1972.9528 - val_loss: 1795.2371
# Epoch 8/100
# 702/702 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 1954.3099 - val_loss: 1788.1750
# Epoch 9/100
# 702/702 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 1928.5002 - val_loss: 1779.0724
# Epoch 10/100
# 702/702 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 1929.2985 - val_loss: 1774.4315
# Epoch 11/100
# 702/702 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 1970.0352 - val_loss: 1769.7416
# Epoch 12/100
# 702/702 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 1934.6914 - val_loss: 1763.9729
# Epoch 13/100
# 702/702 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 1925.0062 - val_loss: 1759.7555
# Epoch 14/100
# 702/702 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 1923.7438 - val_loss: 1756.6309
# Epoch 15/100
# 702/702 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 1895.3069 - val_loss: 1750.7161
# Epoch 16/100
# 702/702 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 1890.9006 - val_loss: 1745.9725
# Epoch 17/100
# 702/702 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 1906.6340 - val_loss: 1741.5266
# Epoch 18/100
# 702/702 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 1895.8408 - val_loss: 1741.7200
# Epoch 19/100
# 702/702 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 1905.3020 - val_loss: 1735.3844
# Epoch 20/100
# 702/702 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 1907.0137 - val_loss: 1729.6583
# Epoch 21/100
# 702/702 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 1888.5918 - val_loss: 1726.2942
# Epoch 22/100
# 702/702 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 1893.0416 - val_loss: 1723.4470
# Epoch 23/100
# 702/702 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 1870.3993 - val_loss: 1720.0968
# Epoch 24/100
# 702/702 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 1881.6230 - val_loss: 1715.8384
# Epoch 25/100
# 702/702 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 1884.0681 - val_loss: 1713.9988
# Epoch 26/100
# 702/702 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 1888.1035 - val_loss: 1710.2130
# Epoch 27/100
# 702/702 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 1877.8137 - val_loss: 1708.5038
# Epoch 28/100
# 702/702 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 1862.9988 - val_loss: 1707.4177
# Epoch 29/100
# 702/702 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 1898.7612 - val_loss: 1707.2914
# Epoch 30/100
# 702/702 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 1837.4226 - val_loss: 1701.6749
# Epoch 31/100
# 702/702 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 1865.1863 - val_loss: 1703.5573
# Epoch 32/100
# 702/702 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 1854.5314 - val_loss: 1702.8032
# Epoch 33/100
# 702/702 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 1847.2870 - val_loss: 1697.9028
# Epoch 34/100
# 702/702 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 1843.3701 - val_loss: 1695.1429
# Epoch 35/100
# 702/702 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 1845.3160 - val_loss: 1699.0198
# Epoch 36/100
# 702/702 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 1850.2886 - val_loss: 1692.9236
# Epoch 37/100
# 702/702 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 1853.4513 - val_loss: 1693.6547
# Epoch 38/100
# 702/702 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 1832.8500 - val_loss: 1693.0867
# Epoch 39/100
# 702/702 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 1844.5486 - val_loss: 1698.2107
# Epoch 40/100
# 702/702 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 1850.6196 - val_loss: 1694.0422
# Epoch 41/100
# 702/702 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 1819.2076 - val_loss: 1691.0546
# Epoch 42/100
# 702/702 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 1878.2601 - val_loss: 1688.5747
# Epoch 43/100
# 702/702 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 1832.5481 - val_loss: 1689.2542
# Epoch 44/100
# 702/702 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 1854.6410 - val_loss: 1692.6411
# Epoch 45/100
# 702/702 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 1840.4869 - val_loss: 1689.2930
# Epoch 46/100
# 702/702 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 1824.9296 - val_loss: 1689.7037
# Epoch 47/100
# 702/702 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 1866.3260 - val_loss: 1690.4187
# Epoch 48/100
# 702/702 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 1843.7078 - val_loss: 1688.1731
# Epoch 49/100
# 702/702 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 1847.1586 - val_loss: 1686.9999
# Epoch 50/100
# 702/702 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 1842.5750 - val_loss: 1691.8998
# Epoch 51/100
# 702/702 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 1840.4954 - val_loss: 1687.9348
# Epoch 52/100
# 702/702 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 1845.2780 - val_loss: 1687.4955
# Epoch 53/100
# 702/702 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 1822.0347 - val_loss: 1691.2875
# Epoch 54/100
# 702/702 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 1826.1803 - val_loss: 1686.3546
# Epoch 55/100
# 702/702 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 1826.8729 - val_loss: 1687.1069
# Epoch 56/100
# 702/702 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 1824.7728 - val_loss: 1686.9916
# Epoch 57/100
# 702/702 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 1831.2566 - val_loss: 1683.5435
# Epoch 58/100
# 702/702 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 1825.4066 - val_loss: 1685.6398
# Epoch 59/100
# 702/702 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 1818.8901 - val_loss: 1683.5286
# Epoch 60/100
# 702/702 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 1853.3932 - val_loss: 1684.4366
# Epoch 61/100
# 702/702 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 1831.8646 - val_loss: 1683.3518
# Epoch 62/100
# 702/702 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 1832.3051 - val_loss: 1686.7773
# Epoch 63/100
# 702/702 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 1860.5643 - val_loss: 1683.9362
# Epoch 64/100
# 702/702 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 1853.9174 - val_loss: 1685.9264
# Epoch 65/100
# 702/702 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 1828.4136 - val_loss: 1684.0752
# Epoch 66/100
# 702/702 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 1837.0148 - val_loss: 1685.2593
# Epoch 67/100
# 702/702 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 1817.9606 - val_loss: 1687.5013
# Epoch 68/100
# 702/702 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 1853.3319 - val_loss: 1682.9490
# Epoch 69/100
# 702/702 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 1842.3694 - val_loss: 1681.1995
# Epoch 70/100
# 702/702 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 1832.2889 - val_loss: 1683.4484
# Epoch 71/100
# 702/702 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 1835.8116 - val_loss: 1681.3258
# Epoch 72/100
# 702/702 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 1806.3693 - val_loss: 1681.6312
# Epoch 73/100
# 702/702 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 1849.9285 - val_loss: 1680.5896
# Epoch 74/100
# 702/702 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 1831.9231 - val_loss: 1682.7886
# Epoch 75/100
# 702/702 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 1808.5490 - val_loss: 1684.1754
# Epoch 76/100
# 702/702 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 1816.0868 - val_loss: 1681.7679
# Epoch 77/100
# 702/702 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 1821.0128 - val_loss: 1682.8969
# Epoch 78/100
# 702/702 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 1838.3060 - val_loss: 1679.9962
# Epoch 79/100
# 702/702 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 1823.0532 - val_loss: 1679.0132
# Epoch 80/100
# 702/702 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 1821.7316 - val_loss: 1681.3080
# Epoch 81/100
# 702/702 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 1836.5215 - val_loss: 1681.6641
# Epoch 82/100
# 702/702 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 1819.8688 - val_loss: 1679.8463
# Epoch 83/100
# 702/702 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 1815.2848 - val_loss: 1679.8507
# Epoch 84/100
# 702/702 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 1824.7935 - val_loss: 1680.9143
# Epoch 85/100
# 702/702 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 1824.0414 - val_loss: 1677.9167
# Epoch 86/100
# 702/702 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 1825.0127 - val_loss: 1679.3278
# Epoch 87/100
# 702/702 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 1816.7266 - val_loss: 1678.9025
# Epoch 88/100
# 702/702 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 1841.2429 - val_loss: 1678.4269
# Epoch 89/100
# 702/702 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 1837.5756 - val_loss: 1677.3331
# Epoch 90/100
# 702/702 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 1824.1978 - val_loss: 1679.3053
# Epoch 91/100
# 702/702 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 1851.2209 - val_loss: 1677.3998
# Epoch 92/100
# 702/702 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 1829.7633 - val_loss: 1680.4084
# Epoch 93/100
# 702/702 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 1821.2653 - val_loss: 1679.1918
# Epoch 94/100
# 702/702 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 1796.2329 - val_loss: 1677.0291
# Epoch 95/100
# 702/702 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 1817.3208 - val_loss: 1675.5781
# Epoch 96/100
# 702/702 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 1830.9856 - val_loss: 1682.2688
# Epoch 97/100
# 702/702 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 1831.1179 - val_loss: 1674.5587
# Epoch 98/100
# 702/702 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 1817.3248 - val_loss: 1677.0688
# Epoch 99/100
# 702/702 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 1843.9919 - val_loss: 1675.2490
# Epoch 100/100
# 702/702 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 1815.2632 - val_loss: 1677.5386
# 220/220 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1710.8102
# MAE del modelo de red neuronal: 1684.9150390625

# %%
import matplotlib.pyplot as plt

# Graficar la pérdida de entrenamiento y validación
plt.plot(history.history['loss'], label='Train Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.xlabel('Época')
plt.ylabel('MAE')
plt.legend()
plt.show()

# %%
model.save('neural_network_85model.h5')
print("Modelo guardado como 'neural_network_model.h5'")
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# Modelo guardado como 'neural_network_model.h5'

# %%
#!pip install shap

# %%
import shap

# Calcular valores SHAP
explainer = shap.Explainer(rf, X_train)
shap_values = explainer(X_test)

# Visualizar valores SHAP
shap.summary_plot(shap_values, X_test)
# Out:
#  99%|===================| 6975/7014 [00:19<00:00]

# %%
import pickle

# Definir el nombre del archivo
filename = 'segundo_modelo.pkl'

# Guardar el modelo en un archivo
with open(filename, 'wb') as file:
    pickle.dump(model, file)

# %%
with open(filename, 'rb') as file:
    loaded_model = pickle.load(file)

# Usar el modelo cargado para hacer predicciones
predicciones = loaded_model.predict(pruebados)
print(predicciones)

# %%
prueba = df_limpio2.iloc[:5]
prueba

# %%
pruebados = prueba[['year', 'kms', 'power','photos','make_number', 'model_number',
               'model_numberdos','prof_int','make_model_ref','cambio_int', 'prof_int', 'km_0_int']]

# %%
prediccionesdos = loaded_model.predict(pruebados)
print(prediccionesdos)

# %%
# Definir los modelos y sus respectivos MAEs
modelos = ['Linear Regression', 'Ridge', 'Lasso', 'Random Forest', 'XGBoost', 'Neural Network']
maes = [maelr, ridge_mae, lasso_mae, rf_mae, xgb_mae, nn_mae]
colores = ['gray', 'gray', 'gray', 'blue', 'blue', 'gray']  # Colores de las barras

# Crear el gráfico de barras
plt.figure(figsize=(10, 6))
bars = plt.bar(modelos, maes, color=colores)

# Agregar etiquetas y títulos
plt.xlabel('Modelos')
plt.ylabel('Mean Absolute Error (MAE)')
plt.title('Comparación de MAE entre modelos')

# Agregar los valores numéricos en las barras
for bar, mae in zip(bars, maes):
    yval = bar.get_height()
    plt.text(bar.get_x() + bar.get_width()/2, yval, round(mae, 2), va='bottom', ha='center', fontsize=10)

# Mostrar el gráfico
plt.tight_layout()
plt.xticks(rotation=45)
plt.show()
